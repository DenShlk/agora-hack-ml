# %%
import numpy as np

# %% [markdown]
# # Load data

# %%
from json import load

with open('agora_hack_products.json', encoding='utf-8') as file:
    all_products = load(file)

all_products
# Out:
# [{'product_id': '0007302f2fe1d54d',
#   'name': 'Классическая сплит-система ROYAL CLIMA PANDORA RC-PD28HN, для комнат до 28 кв.метра, настенный кондиционер для дома/офиса, комплект',
#   'props': ['Класс  энергоэффективности\tA',
#    'Мощность  кондиционера\t9 BTU',
#    'Уровень  шума внутреннего блока\t21.5 дБ - 38 дБ',
#    'Режим   работы\tохлаждение / обогрев',
#    'Фильтр тонкой очистки\tесть',
#    'Доп.   режимы турбо, экорежим, осушение, ночной, вентиляция'],
#   'is_reference': False,
#   'reference_id': 'f497219eb0077f84'},
#  {'product_id': '000740b6c1cc763e',
#   'name': 'Смартфон Xiaomi Redmi Note 10S NFC 6/128 ГБ RU, белоснежная галька',
#   'props': ['Экран\t6.43" (2400x1080) AMOLED 60 Гц',
#    '4 камеры 8 МП, 64 МП, 2 МП, 2 МП',
#    'Беспроводные интерфейсы инфракрасный порт (IRDA), Bluetooth, Wi-Fi, NFC',
#    'Встроенная   память\t128 ГБ',
#    'Оперативная   память\t6 ГБ',
#    'Аккумулятор\t5000  мА·ч',
#    'MediaTek   Helio G95',
#    'SIM-карты\t2  (nano SIM)',
#    'Операционная  система\tAndroid 11',
#    'Степень  защиты\tIP53',
#    'Вес\t179  г',
#    'Стандарт   связи 2G, 4G LTE, 3G'],
#   'is_reference': True,
#   'reference_id': None},
#  {'product_id': '0039af5efceac4ab',
#   'name': 'Холодильник Бирюса 118',
#   'props': ['Мощность  замораживания  4 кг/сутки'],
#   'is_reference': False,
#   'reference_id': '28085e941cde1639'},
#  {'product_id': '004f2158acb8165c',
#   'name': 'ASUS TUF-GTX1660S-O6G-GAMING Видеокарта',
#   'props': ['Объем  видеопамяти\t6144 МБ',
#    'Частота  памяти\t14002 МГц',
#    'Разъемы   и интерфейсы выход DVI, выход DisplayPort, выход HDMI'],
#   'is_reference': False,
#   'reference_id': '9afe55bb4bf1e8a8'},
#  {'product_id': '005cddb29e1677ec',
#   'name': 'Кофемашина Saeco Lirika One Touch Cappuccino, серебристый',
#   'props': ['Приготовление  капучино\tавтоматическое',
#    'Материал   корпуса\tпластик',
#    'Настройки крепость кофе, объем порции горячей воды',
#    'Доп.  функции автоматическая декальцинация, подача горячей воды, автоотключение при неиспользовании'],
#   'is_reference': False,
#   'reference_id': '1f21918ceb5d345c'},
#  {'product_id': '0083737f904dd9a9',
#   'name': 'Фен LUMME LU-1058',
#   'props': ['Мощность\t1400 Вт',
#    'Насадки\tконцентратор',
#    'Вес\t350  г',
#    'Особенности   складная ручка, защита от перегрева, петля для подвешивания'],
#   'is_reference': True,
#   'reference_id': None},
#  {'product_id': '0083dddef6bc6503',
#   'name': 'Lenovo 62A8KAT1EU Монитор',
#   'props': ['Яркость\t250   кд/м²; контрастность: 1000:1'],
#   'is_reference': False,
#   'reference_id': '8f9c8fcf9cb2862c'},
#  {'product_id': '0089cfc44012ac3c',
#   'name': 'Наушники Xiaomi Buds 3 Black',
#   'props': ['Конструкция\tвнутриканальные',
#    'Конструктивные  особенности\tмикрофон',
#    'Тип  устройства\tбеспроводные TWS-наушники'],
#   'is_reference': False,
#   'reference_id': 'f4d135a1d7a3b3a0'},
#  {'product_id': '00d03054afa45fdf',
#   'name': 'Газовая Плита Гефест ПГ 700-02 Газовая Плита Гефест ПГ 700-02',
#   'props': ['Материал рабочей поверхности\tэмалированная сталь',
#    'Настольная\tда',
#    'ШхВхГ\t50х10х37.40  см'],
#   'is_reference': False,
#   'reference_id': '116c9e6140857b4b'},
#  {'product_id': '00d094e2dbd04434',
#   'name': 'Ноутбук Lenovo IdeaPad L340-15API 81LW00A3RK 300U/8GB/128GB SSD/Radeon Vega 3/15.6" Full HD/Wi-Fi/B/cam/no ОС/чёрный',
#   'props': ['Процессор\tAMD   Athlon 300U (2x2.40 ГГц)',
#    'Видеокарта AMD Radeon Vega 3, встроенная'],
#   'is_reference': False,
#   'reference_id': 'db2864373795ea53'},
#  {'product_id': '00d72c9fe99ed892',
#   'name': 'Видеокарта MSI PCI-E GeForce GTX 1050 Ti 4GT OC nVidia GeForce GTX 1050TI 4096Mb 128bit GDDR5 1341/7008 DVIx1/HDMIx1/DPx1/HDCP Ret',
#   'props': ['Комплектация\tRetail',
#    'Область применения\tигровая',
#    'Тип памяти\tGDDR5',
#    'Техпроцесс\t14   нм',
#    'Количество   поддерживаемых мониторов\t3',
#    'Объем  видеопамяти\t4096 МБ',
#    'Частота  памяти\t7008 МГц',
#    'Шина   обмена с памятью\t128 бит',
#    'Тип   подключения\tPCI Express 3.0'],
#   'is_reference': False,
#   'reference_id': '31862a08efb59198'},
#  {'product_id': '00dd96a6503b1ade',
#   'name': '50" Телевизор Samsung UE50AU7002U 2022, черный',
#   'props': ['Разъемы и интерфейсы слот CI/CI+, вход HDMI x 2, Ethernet - RJ-45'],
#   'is_reference': False,
#   'reference_id': '2215bb3c753bac5a'},
#  {'product_id': '00fa8419a6d81d79',
#   'name': 'Холодильник Nord NR 506 W',
#   'props': ['Класс энергопотребления A+',
#    'Особенности конструкции перевешиваемые двери',
#    'Размораживание холодильной камеры капельная система',
#    'Общий  объем 60 л'],
#   'is_reference': False,
#   'reference_id': '5d3fa3ae27980116'},
#  {'product_id': '0105fb7b4dd8634b',
#   'name': 'Видеокарта Sinotex Ninja GeForce GT 740 2 Gb (NH74NP025F)',
#   'props': ['Техпроцесс\t28 нм',
#    'Максимальное   разрешение\t4096x2160',
#    'Шина   обмена с памятью\t128 бит',
#    'Частота   памяти\t5000 МГц'],
#   'is_reference': False,
#   'reference_id': 'd0c64830aa5b693c'},
#  {'product_id': '01378fa92f901df5',
#   'name': '15.6" Ноутбук Lenovo IdeaPad 3 15ARE05 1920x1080, AMD Ryzen 5 4500U 2.3 ГГц, SSD 256 ГБ, AMD Radeon Graphics, DOS, 81W40033RK, Platinum Grey',
#   'props': ['Экран\t15.6"  (1920x1080) IPS',
#    'Процессор\tAMD   Ryzen 5 4500U (6x2.30 ГГц)',
#    'Время   работы от аккумулятора\t14 ч',
#    'Операционная  система\tDOS',
#    'Память  RAM 4 ГБ (2666 МГц), SSD 256 ГБ',
#    'Видеокарта   AMD Radeon Graphics, встроенная'],
#   'is_reference': True,
#   'reference_id': None},
#  {'product_id': '013c2a3c1dfe4b24',
#   'name': 'Принтер Kyocera FS-1040 <Лазерный, 20стр/мин, 600dpi, USB2.0, A4',
#   'props': ['Назначение\tдля   небольшого офиса'],
#   'is_reference': False,
#   'reference_id': 'b06b981adc52c752'},
#  {'product_id': '013d55651426863d',
#   'name': 'ABC Видеокарта MSI Radeon RX 6500 XT MECH 2X 4G OC (Radeon RX 6500 XT, 4ГБ GDDR6, HDMI, DP) (PCI-E) (ret)',
#   'props': ['Комплектация\tRetail',
#    'Объем   видеопамяти\t4096 МБ',
#    'Частота   памяти\t18000 МГц',
#    'Разъемы  и интерфейсы выход DisplayPort, выход HDMI'],
#   'is_reference': False,
#   'reference_id': '5cd2febf56f0e483'},
#  {'product_id': '013d9f49a19db898',
#   'name': 'Водонагреватель thermex ic 10 u, накопительный, 1.5квт, 10л, белый [эдэб01497]',
#   'props': ['Время   нагрева\t28 мин'],
#   'is_reference': False,
#   'reference_id': 'd4fe7179ce05fe85'},
#  {'product_id': '015f996021a0a530',
#   'name': 'Gembird Акустическая система стерео Gembird SPK-203, 2x3Вт, черный (ret)',
#   'props': ['Диапазон   частот 80 - 20000 Гц',
#    'Материал   корпуса колонок',
#    'Однополосные   колонки'],
#   'is_reference': False,
#   'reference_id': 'a8d71ac2f5a72530'},
#  {'product_id': '01601abb0bf5133d',
#   'name': 'Микроволновая печь Hyundai HYM-D2071, серебристый',
#   'props': ['Объем\t20 л',
#    'Переключатели\tкнопочные',
#    'Мощность  микроволн\t700 Вт',
#    'Внутреннее  покрытие камеры\tэмаль',
#    'Диаметр   поддона\t245 мм',
#    'Режимы   работы\tразморозка',
#    'ШхВхГ\t45.10х28.50х32.60  см',
#    'Особенности  функция задержки пуска, подсветка камеры, дисплей, блокировка от детей, утапливаемые переключатели',
#    'Доп.   режимы программирование процесса приготовления, автоматическое приготовление, автоматическая разморозка, звуковой сигнал отключения, ускоренный разогрев'],
#   'is_reference': True,
#   'reference_id': None},
#  {'product_id': '01613fb413f4ccce',
#   'name': 'Xiaomi Mi Robot Vacuum Mop 2 Pro White [BHR5044EU] Робот пылесос',
#   'props': ['Объем  контейнера для пыли\t0.45 л',
#    'Работа  от аккумулятора\tдо 110 мин'],
#   'is_reference': False,
#   'reference_id': '516c4c0cca619ea4'},
#  {'product_id': '0165ad28a6322088',
#   'name': 'Krona KAMAYA 45 BI',
#   'props': ['Тип\tузкая',
#    'Ширина\t44.9 см',
#    'Третий  уровень загрузки\tесть',
#    '3-й   разбрызгиватель\tесть',
#    'Таймер  отсрочки запуска\tесть',
#    'Число  программ 8, класс мойки: A'],
#   'is_reference': False,
#   'reference_id': '68ccf6102657986b'},
#  {'product_id': '01a28e17323d6ef8',
#   'name': 'Принтер лазерный Xerox Phaser 3020BI',
#   'props': ['Интерфейсы USB, Wi-Fi, AirPrint',
#    'Назначение\tдля   небольшого офиса',
#    'Печать\tчерно-белая  лазерная',
#    'Макс.   формат печати\tA4 (210 × 297 мм)'],
#   'is_reference': True,
#   'reference_id': None},
#  {'product_id': '01a896d8507b1519',
#   'name': 'Кофемашина Beko CEG5331X (нержавеющая сталь)',
#   'props': ['Приготовление   капучино\tавтоматическое',
#    'Тип используемого кофе\tзерновой',
#    'Настройки температура кофе, объем порции горячей воды',
#    'Доп.  функции автоотключение при неиспользовании, автоматическая декальцинация, подача горячей воды',
#    'Особенности   конструкции индикатор включения, индикатор уровня воды, съемный лоток для сбора капель, контейнер для отходов, дисплей'],
#   'is_reference': False,
#   'reference_id': '698c2d3015a71ee7'},
#  {'product_id': '01c4a011efa3ffc4',
#   'name': 'Сплит система Jax ACN-09HE',
#   'props': ['Мощность  охлаждения\t2500 Вт / обогрева: 2500 Вт'],
#   'is_reference': False,
#   'reference_id': '664b48a4aafdf9cf'},
#  {'product_id': '01c7e6328de0cfc6',
#   'name': 'Беспроводные наушники Apple AirPods 3, белый',
#   'props': ['Конструкция\tвкладыши   (открытые)',
#    'Время работы\t6 ч',
#    'Тип  излучателей\tдинамические',
#    'Количество микрофонов\t4',
#    'Подключение\tBluetooth   5.0',
#    'Тип зарядки кейса беспроводная зарядка, Lightning'],
#   'is_reference': False,
#   'reference_id': '3f844bec1d74466d'},
#  {'product_id': '01ca9b62958f93e1',
#   'name': 'F840-100 Melitta Caffeo Barista T Smart',
#   'props': ['Тип используемого кофе\tмолотый / зерновой',
#    'Материал корпуса\tпластик',
#    'Приготовление  капучино\tавтоматическое',
#    'Настройки  температура кофе, объем порции горячей воды, жесткость воды, крепость кофе'],
#   'is_reference': False,
#   'reference_id': 'a05ae39cb2ace0f4'},
#  {'product_id': '01e2d8af90f8a150',
#   'name': 'Монитор 23.8" Lenovo C24-20 black (WVA, 1920x1080, 16:9, 178/178, 250cd/m2, 1000:1, 4ms, VGA, HDMI) (62A8KAT1EU)',
#   'props': ['Яркость\t250 кд/м²; контрастность: 1000:1'],
#   'is_reference': False,
#   'reference_id': '8f9c8fcf9cb2862c'},
#  {'product_id': '01e52344308143f6',
#   'name': 'Газовая плита Weissgauff WGS G4G02 WS, белый',
#   'props': ['Объем духовки\t60 л',
#    'Управление\tмеханическое',
#    'Газ-контроль\tдуховки',
#    'Очистка духовки\tтрадиционная',
#    'Особенности конструкции\tящик для посуды',
#    'ШхВхГ\t50х85х60 см',
#    'Тип   духовки\tгазовая',
#    'Возможность  подключения к газовому баллону\tесть'],
#   'is_reference': True,
#   'reference_id': None},
#  {'product_id': '0213b4e3f71ad7c2',
#   'name': 'Индукционная плитка Gorenje ICE2000SP',
#   'props': ['Особенности конструкции\tдисплей',
#    'Материал рабочей поверхности\tстеклокерамика',
#    'Доп.  функции\tтаймер'],
#   'is_reference': False,
#   'reference_id': 'c74b2d4c1e6a99b3'},
#  {'product_id': '021a79af196c9475',
#   'name': 'Видеокарта MSI GeForce RTX 3050 8 ГБ (RTX 3050 VENTUS 2X 8G OC), rev. 2.0 (LHR)',
#   'props': ['Частота видеопроцессора\t1807 МГц',
#    'Техпроцесс\t8 нм',
#    'Тип памяти\tGDDR6',
#    'Комплектация\tRetail',
#    'Разъемы и интерфейсы выход HDMI, выход DisplayPort x 3',
#    'Разъем   дополнительного питания\t8 pin',
#    'Тип  подключения\tPCI Express 4.0',
#    'Частота  памяти\t14000 МГц',
#    'TDP\t130   Вт',
#    'Поддержка  технологий поддержка HDCP, поддержка CUDA, поддержка Vulkan, поддержка трассировки лучей'],
#   'is_reference': False,
#   'reference_id': 'dbacf1a8aab6c261'},
#  {'product_id': '021c38f14059b080',
#   'name': 'Видеокарта Gigabyte PCI-E 4.0 GV-N3080GAMING OC-12GD LHR NVIDIA GeForce RTX 3080 12288Mb 320 GDDR6X 1755/19000 HDMIx2 DPx3 HDCP Ret',
#   'props': ['Шина обмена с памятью\t384 бит',
#    'Область применения\tигровая',
#    'Техпроцесс\t8 нм',
#    'Максимальное   разрешение\t7680x4320',
#    'TDP\t350  Вт',
#    'Разъемы   и интерфейсы выход DisplayPort x 3, выход HDMI'],
#   'is_reference': False,
#   'reference_id': '9158a4c6707ede74'},
#  {'product_id': '0229abcf2ded1058',
#   'name': 'Кофемашина Nivona CafeRomatica NICR 525',
#   'props': ['Давление помпы\t15 бар',
#    'Количество степеней помола\t3',
#    'Настройки температура кофе, крепость кофе, жесткость воды',
#    'Тип  используемого кофе\tмолотый / зерновой',
#    'Приготовление  капучино\tавтоматическое',
#    'Одновременная   раздача на 2 чашки\tда',
#    'Материал   корпуса\tпластик',
#    'Тип   напитка эспрессо, латте, капучино, американо',
#    'Доп.   функции подача горячей воды, автоотключение при неиспользовании, автоматическая декальцинация',
#    'Особенности  конструкции отсек для шнура, дисплей, индикатор включения, индикатор уровня воды, съемный лоток для сбора капель'],
#   'is_reference': True,
#   'reference_id': None},
#  {'product_id': '022c4ffba27108e2',
#   'name': 'Беспроводные наушники Xiaomi Redmi Buds 3 Pro, серый ледник',
#   'props': ['Активное шумоподавление (ANC)\tесть',
#    'Импеданс\t32  Ом',
#    'Подключение\tBluetooth  5.2',
#    'Количество  микрофонов\t3',
#    'Время  работы от аккумулятора в кейсе\t28 ч',
#    'Степень   защиты\tIPX4',
#    'Диапазон  воспроизводимых частот\t20-20000 Гц',
#    'Тип   зарядки кейса USB Type-C, беспроводная зарядка'],
#   'is_reference': False,
#   'reference_id': '7f0e67ce52682515'},
#  {'product_id': '022d34f6e6443cc7',
#   'name': 'TP-Link ER605 TL-R605 SafeStream гигабитный Multi-WAN VPN маршрутизатор',
#   'props': ['Возможность установки в стойку\tесть',
#    'Количество   WAN-портов\t3',
#    'Особенности\tUSB-порт',
#    'Количество   LAN-портов\t1',
#    'Сетевые стандарты IEEE 802.3x, IEEE 802.3ab, IEEE 802.3u, IEEE 802.1q (VLAN)',
#    '1  гигабитный порт WAN, 3 гигабитных порта WAN/LAN, 1 гигабитный порт LAN; количество одновременных сессий кабель Ethernet RJ45, 25000 (TL-R605) и 30000 (ER605); комплектация: адаптер питания, руководство по быстрой настройке'],
#   'is_reference': False,
#   'reference_id': '0ab98256ef22b592'},
#  {'product_id': '0240c3be4a47dc1e',
#   'name': 'Korting Посудомоечная машина полновстраиваемая KORTING KDI 45570',
#   'props': ['3-й   разбрызгиватель\tесть',
#    'Индикация на полу\tлуч',
#    'Вместимость\t10 комплектов',
#    'Тип защиты от протечек\tполная',
#    'Ширина\t45  см',
#    'Таймер  отсрочки запуска\tесть',
#    'Число   программ 8, класс мойки: A'],
#   'is_reference': False,
#   'reference_id': 'f325184a5c99c599'},
#  {'product_id': '0279f00096211377',
#   'name': 'Wi-Fi роутер/точка доступа TP-LINK Archer C54',
#   'props': ['Частотный   диапазон устройств Wi-Fi\t2.4 / 5 ГГц (одновременная работа)',
#    'Макс.   скорость беспроводного соединения 1167 Мбит/с',
#    'Стандарт  Wi-Fi 802.11 b (Wi-Fi 1), g (Wi-Fi 3), ac (Wi-Fi 5), n (Wi-Fi 4), a (Wi-Fi 2)'],
#   'is_reference': False,
#   'reference_id': '619891c75facdfd3'},
#  {'product_id': '0286b2e3b87abe15',
#   'name': 'PCI-E x16 GeForce GT 1030 ASUS GT1030-SL-2G-BRK, 2GB DDR5 (RTL)',
#   'props': ['Разъемы  и интерфейсы выход HDMI, выход DVI',
#    'Комплектация\tRetail',
#    'Тип подключения\tPCI Express 3.0',
#    'Область   применения\tигровая',
#    'Техпроцесс\t14   нм',
#    'TDP\t30   Вт',
#    'Максимальное   разрешение\t4096x2160',
#    'Шина  обмена с памятью\t64 бит'],
#   'is_reference': False,
#   'reference_id': 'e09b76f558f1befe'},
#  {'product_id': '028be720c37aae99',
#   'name': 'ASUS Монитор 24" ASUS VA24DQLB (90LM0541-B01370)',
#   'props': ['Тип   матрицы\tIPS',
#    'Экран\t1920x1080   (16:9)',
#    'Покрытие экрана\tантибликовое'],
#   'is_reference': False,
#   'reference_id': 'be85c7f8554f16c0'},
#  {'product_id': '0295babfe47a46b9',
#   'name': 'Samsung SM-A336E Galaxy A33 5G 128 6Gb черный SM-A336EZKGMEA',
#   'props': ['Степень   защиты\tIP67',
#    'Экран\t6.4"  (2400x1080) Super AMOLED 90 Гц',
#    'Встроенная   память\t128 ГБ',
#    'Вес\t186   г',
#    'Операционная   система\tAndroid 12',
#    'Стандарт  связи 5G, 2G, 4G LTE, 3G',
#    '4   камеры 5 МП, 48 МП, 8 МП, 2 МП'],
#   'is_reference': False,
#   'reference_id': '161fca3b6bcf5fcc'},
#  {'product_id': '0298922108dfae57',
#   'name': 'Видеокарта MSI PCI-E 4.0 RTX 3070 Ti GAMING X TRIO 8G NV RTX3070TI 8192Mb 256 GDDR6X 1830/19000/HDMI',
#   'props': ['TDP\t310 Вт',
#    'Техпроцесс\t8 нм',
#    'Частота  видеопроцессора\t1830 МГц',
#    'Тип   памяти\tGDDR6X',
#    'Разъем   дополнительного питания\t8 pin + 8 pin',
#    'Тип   подключения\tPCI Express 4.0',
#    'Количество  поддерживаемых мониторов\t4',
#    'Объем  видеопамяти\t8192 МБ',
#    'Шина  обмена с памятью\t256 бит',
#    'Разъемы   и интерфейсы выход HDMI, выход DisplayPort x 3'],
#   'is_reference': False,
#   'reference_id': '58330809dae8fcad'},
#  {'product_id': '02a4217e7281bcbd',
#   'name': 'Беспроводные наушники Samsung Galaxy Buds2 RU, черный',
#   'props': ['Тип зарядки кейса\tбеспроводная зарядка',
#    'Конструкция\tвнутриканальные',
#    'Количество микрофонов\t3',
#    'Активное   шумоподавление (ANC)\tесть',
#    'Вес\t41.2   г',
#    'Степень   защиты\tIPX2',
#    'Время  работы от аккумулятора в кейсе\t29 ч'],
#   'is_reference': False,
#   'reference_id': '6b423ba12a723c38'},
#  {'product_id': '02aa2dcbe4ef2839',
#   'name': 'Газовая плита BEKO FSS 53000 DW',
#   'props': ['Управление\tмеханическое',
#    'Газ-контроль\tконфорок',
#    'Гриль\tэлектрический',
#    'Объем  духовки\t60 л',
#    'Доп.   функции\tтермостат',
#    'Тип   духовки\tэлектрическая',
#    'Максимальная   температура в духовке\t250 °C',
#    'Материал   рабочей поверхности\tэмалированная сталь'],
#   'is_reference': False,
#   'reference_id': 'debaf87e85f94b1c'},
#  {'product_id': '02c90cd809fafba4',
#   'name': 'Микроволновая печь SAMSUNG GE88SUW/BW, объем 23 л, мощность 800 Вт, гриль, электронное управление, белая',
#   'props': ['Переключатели\tкнопочные',
#    'Мощность  микроволн\t800 Вт',
#    'ШхВхГ\t48.90х27.50х36  см',
#    'Объем\t23  л',
#    'Особенности блокировка от детей, кнопка +30 секунд, подсветка камеры, дисплей',
#    'Режимы работы гриль, микроволны + гриль, разморозка'],
#   'is_reference': False,
#   'reference_id': '35dcbf60d7bbfcee'},
#  {'product_id': '02c9853e1de1d245',
#   'name': 'Многофункциональное устройство HP Color LaserJet Pro M479fdn (W1A79A)',
#   'props': ['Скорость\t27 стр/мин (цветн. А4)',
#    'Макс. размер отпечатка\t216 × 356 мм',
#    'Особенности\tавтоматическая двусторонняя печать',
#    'Интерфейсы AirPrint, USB, Ethernet (RJ-45)',
#    'Цветной  ЖК-дисплей\tда',
#    'Макс.   формат печати\tA4 (210 × 297 мм)',
#    'Функции   копирование, отправка изображения по e-mail, сканирование'],
#   'is_reference': False,
#   'reference_id': '08d814610482da4a'},
#  {'product_id': '02d9a8371f1c277b',
#   'name': 'Настольная плитка OLTO HP-101I 1237291',
#   'props': ['Управление\tэлектронное',
#    'Макс.   потребляемая мощность\t2000 Вт',
#    'Защитное   отключение конфорок',
#    'Материал   рабочей поверхности\tстеклокерамика'],
#   'is_reference': False,
#   'reference_id': '74d0d86e83e8cfbd'},
#  {'product_id': '02ffdc2294e78465',
#   'name': 'Акустика GiNZZU GM-427',
#   'props': ['MDF', 'MDF'],
#   'is_reference': False,
#   'reference_id': 'cfc2b5f5c0fa69dd'},
#  {'product_id': '030e1066a542b003',
#   'name': '27" Монитор Lenovo G27c-10, 1920x1080, 165 Гц, *VA, черный',
#   'props': ['Интерфейсы вход DisplayPort, вход HDMI',
#    'Особенности  подсветка без мерцания (Flicker-Free), регулировка по высоте'],
#   'is_reference': False,
#   'reference_id': 'b941b65ba33a29a0'},
#  {'product_id': '031818aab675f618',
#   'name': 'Наушники Redmi Buds 3 Lite M2110E1 (White) (BHR5490GL)',
#   'props': ['Время   работы от аккумулятора в кейсе\t18 ч',
#    'Тип излучателей\tдинамические',
#    'Тип  зарядки кейса\tUSB Type-C',
#    'Степень  защиты\tIP54',
#    'Вес\t8.4  г'],
#   'is_reference': False,
#   'reference_id': 'c24cbf788d7f1d47'},
#  {'product_id': '0324149277999333',
#   'name': 'Робот-пылесос Xiaomi Viomi Vacuum Cleaning Robot V2 Pro black',
#   'props': ['Объем   контейнера для пыли\t0.3 л',
#    'Комплектация   боковая щетка, электрощетка'],
#   'is_reference': False,
#   'reference_id': 'b91a686bdeee3b59'},
#  {'product_id': '03342f9abe116e06',
#   'name': 'Сплит-система ELECTROLUX EACS-09HAT/N3 (из 2 частей), 1556533',
#   'props': ['Мощность охлаждения\t2640 Вт / обогрева: 2780 Вт',
#    'Площадь  помещения\t25 м²',
#    'Класс  энергоэффективности\tA',
#    'Уровень   шума внутреннего блока\t28 дБ',
#    'Доп.  режимы ночной, вентиляция, осушение'],
#   'is_reference': False,
#   'reference_id': 'f3e10061c5a04f2c'},
#  {'product_id': '03744623d7138dac',
#   'name': 'Электроплитка OLTO HP-101I черный',
#   'props': ['Материал рабочей поверхности\tстеклокерамика',
#    'Макс.   потребляемая мощность\t2000 Вт'],
#   'is_reference': False,
#   'reference_id': '74d0d86e83e8cfbd'},
#  {'product_id': '037ddc6d141b43a5',
#   'name': 'Накопительный электрический водонагреватель ariston blu evo r 30 ru, 2019 г, белый/синий',
#   'props': ['Потребляемая мощность\t1500 Вт',
#    'Время нагрева\t70 мин',
#    "Установка\tвертикальная   на стену с нижней подводкой (½')",
#    'Размеры  (ШxВxГ)\t447x447x389 мм'],
#   'is_reference': False,
#   'reference_id': '1a3d1cb265de4c4e'},
#  {'product_id': '03885e170ec2a155',
#   'name': 'Сплит система классический кондиционер Daichi AIR AIR20AVQ1/AIR20FV1',
#   'props': ['Цвет  товара\tбелый', 'Площадь  помещения\t20 м²'],
#   'is_reference': False,
#   'reference_id': 'd307989eecbe7f7b'},
#  {'product_id': '0399dcbd87579459',
#   'name': 'Микроволновая печь LG MW25R35GISW, белый',
#   'props': ['Доп.  режимы звуковой сигнал отключения, автоматическое приготовление, автоматическая разморозка',
#    'Диаметр поддона\t292 мм',
#    'Переключатели\tсенсорные',
#    'Инверторное   управление мощностью\tда',
#    'Мощность  микроволн\t1000 Вт',
#    'Объем\t25  л',
#    'Внутреннее  покрытие камеры\tэмаль'],
#   'is_reference': False,
#   'reference_id': '46889124439ddfa4'},
#  {'product_id': '03a1c5115743413a',
#   'name': 'Монитор 25" Lenovo G25-10 черный (65fegac2eu)',
#   'props': ['Тип матрицы\tTN',
#    'Яркость\t400 кд/м²; контрастность: 1000:1',
#    'Интерфейсы вход HDMI, вход DisplayPort',
#    'Поддержка FreeSync/G-Sync G-Sync, FreeSync Premium',
#    'Экран\t1920x1080   (16:9)',
#    'Игровой  монитор\tда',
#    'Покрытие   экрана матовое, антибликовое'],
#   'is_reference': False,
#   'reference_id': 'a51a43ae8ef6ec5d'},
#  {'product_id': '03aa52316ed25ab9',
#   'name': 'Индукционная настольная плитка Olto HP-101I',
#   'props': ['Особенности  конструкции\tдисплей',
#    'Материал   рабочей поверхности\tстеклокерамика',
#    'Доп.   функции\tтаймер',
#    'Защитное   отключение конфорок'],
#   'is_reference': False,
#   'reference_id': '74d0d86e83e8cfbd'},
#  {'product_id': '03aed7037623ee8f',
#   'name': 'Процессор Intel Core I9-12900K S1700 OEM (CM8071504549230 S RL4H)',
#   'props': ['Количество потоков\t24',
#    'Сокет   LGA1700',
#    'Тепловыделение   241 Вт'],
#   'is_reference': False,
#   'reference_id': '92d355d0c4a7e069'},
#  {'product_id': '03afb96ef0b20177',
#   'name': 'Робот-пылесос Roborock S7 (Чёрный Global)',
#   'props': ['Объем контейнера для пыли\t0.47 л',
#    'Тип   датчиков\tинфракрасные/ультразвуковые',
#    'ШхГхВ\t35x35.30x9.60  см',
#    'Тип   уборки\tсухая и влажная',
#    'Особенности  конструкции мягкий бампер, встроенные часы, лидар',
#    'Режимы   работы местная уборка, быстрая уборка, движение вдоль стен, движение по спирали, движение зигзагом',
#    'Комплектация  турбощетка, электрощетка, боковая щетка'],
#   'is_reference': False,
#   'reference_id': '70dda99f86242098'},
#  {'product_id': '03bd8507cd4a2124',
#   'name': 'Сплит-система Hyundai HAC-09/T-PRO',
#   'props': ['Площадь помещения\t25 м²',
#    'Класс энергоэффективности\tA',
#    'Режим работы\tохлаждение / обогрев',
#    'Цвет  товара\tбелый',
#    'Доп.   режимы ночной, осушение, вентиляция'],
#   'is_reference': False,
#   'reference_id': 'f35afc760cecb50f'},
#  {'product_id': '03bf7c9e494b4037',
#   'name': 'Беспроводные наушники Xiaomi Redmi Buds 3 Lite White BHR5490GL',
#   'props': ['Степень защиты\tIP54',
#    'Тип зарядки кейса\tUSB Type-C',
#    'Активное шумоподавление (ANC)\tесть',
#    'Тип   излучателей\tдинамические',
#    'Время   работы от аккумулятора в кейсе\t18 ч',
#    'Время  работы\t5 ч',
#    'Вес\t8.4  г'],
#   'is_reference': False,
#   'reference_id': 'c24cbf788d7f1d47'},
#  {'product_id': '03c1c4ff96198648',
#   'name': 'Монитор LENOVO LCD 22" S22E-20 62C6KAT1EU, черный',
#   'props': ['Поддержка FreeSync/G-Sync\tFreeSync',
#    'Яркость\t250  кд/м²; контрастность: 3000:1',
#    'Частота  обновления\t75 Гц; отклик: 4 мс',
#    'Экран\t1920x1080   (16:9)',
#    'Тип   матрицы\t*VA',
#    'Интерфейсы  вход VGA, вход HDMI'],
#   'is_reference': False,
#   'reference_id': '73c8a97445f43966'},
#  {'product_id': '03d20135537ed33a',
#   'name': 'Настольная плита Energy EN-904В',
#   'props': ['Настольная\tда',
#    'Материал  рабочей поверхности\tэмалированная сталь',
#    'Макс.   потребляемая мощность\t2000 Вт'],
#   'is_reference': False,
#   'reference_id': '6ba3b74a1ca138cf'},
#  {'product_id': '03d4cbad955f9832',
#   'name': 'Плита Электрическая Weissgauff WES E2V12 WS белый',
#   'props': ['ШхВхГ\t50х87х60 см',
#    'Тип   духовки\tэлектрическая',
#    'Доп.  функции\tтермостат',
#    'Особенности   конструкции ящик для посуды, эмаль легкой чистки'],
#   'is_reference': False,
#   'reference_id': '1f3709ce593ece4a'},
#  {'product_id': '03d9b39c9dbd9f6a',
#   'name': 'Робот-пылесос Xiaomi Viomi Vacuum Cleaning Robot V3 black (V-RVCLM26B) Без ограничений',
#   'props': ['ШхГхВ\t35x35x9.50 см',
#    'Особенности конструкции встроенные часы, мягкий бампер',
#    'Режимы   работы местная уборка, движение зигзагом'],
#   'is_reference': False,
#   'reference_id': '1c370548bdb8590d'},
#  {'product_id': '03e8709e0ed82f70',
#   'name': 'Посудомоечная машина Bosch SPV 6 HMX 4 MR',
#   'props': ['Тип защиты от протечек\tполная',
#    'Защита защита от детей, защита от протечек',
#    'Индикация   на полу\tвремя до завершения мойки',
#    'Управление  со смартфона\tда',
#    'Таймер  отсрочки запуска\tесть',
#    'Тип   сушки интенсивная, класс A'],
#   'is_reference': False,
#   'reference_id': '5feb5e5d2a37e729'},
#  {'product_id': '03eaec9cede74113',
#   'name': '14" Ноутбук HONOR MagicBook X 14NBR-WAI9 (1920x1080, Intel Core i3 2.1 ГГц, RAM 8 ГБ, SSD 256 ГБ, Win10 Home), 53011TVN-001, серый',
#   'props': ['Память  SSD 256 ГБ, RAM 8 ГБ (2666 МГц)',
#    'Процессор\tIntel  Core i3 10110U (2x2.10 ГГц)'],
#   'is_reference': False,
#   'reference_id': '09824205ce94d7c9'},
#  {'product_id': '04072ddceda6a216',
#   'name': "IdeaPad 5 Pro 14ITL6 14.0'' 2.2K (2440x1400) IPS/Intel Core i5-1135G7 2.40GHz Quad/16GB/512GB SSD/Integrated/WiFi/5.2/HD Web",
#   'props': ['Время   работы от аккумулятора\t10 ч'],
#   'is_reference': False,
#   'reference_id': 'a97b2ca22a6393b3'},
#  {'product_id': '046d69b95dd39368',
#   'name': 'Встраиваемая стиральная машина KRONA KALISA 1400 8K WHITE',
#   'props': ['Установка\tвстраиваемая',
#    'ШхГхВ\t59.70х54.40х81.70   см',
#    'Загрузка\t8   кг',
#    'Доп.функции  контроль баланса, выбор температуры стирки, выбор скорости отжима, отложенный старт, контроль за уровнем пены'],
#   'is_reference': False,
#   'reference_id': '9ebdb1e8f6e7d472'},
#  {'product_id': '0474b6aa18eb7d69',
#   'name': 'СВЧ-печь LG MS-20R42 D',
#   'props': ['Объем\t20  л',
#    'Режимы   работы\tразморозка',
#    'Переключатели   кнопочные, сенсорные',
#    'Доп.  режимы ускоренная разморозка, автоматическая разморозка, автоматическое приготовление, звуковой сигнал отключения'],
#   'is_reference': False,
#   'reference_id': 'f1d7a6de205f4c9e'},
#  {'product_id': '049bbd1db2df0018',
#   'name': 'Фен Babyliss 6704E, 2000W',
#   'props': ['Число  режимов нагрева\t2',
#    'Насадки\tконцентратор',
#    'Особенности защита от перегрева, петля для подвешивания',
#    'Дополнительные функции независимая регулировка нагрева и воздушного потока, подача холодного воздуха'],
#   'is_reference': False,
#   'reference_id': '84fd7990c2a3e568'},
#  {'product_id': '04b3805042716f0f',
#   'name': 'Телевизор Xiaomi Mi TV 5 65 Pro 2019 QLED, HDR CN',
#   'props': ['Платформа Smart TV\tAndroid',
#    'Разрешение\t3840x2160',
#    'Разрешение  HD\t4K UHD',
#    'Экосистема  умного дома\tXiaomi Mi Home',
#    'Год  создания модели\t2019',
#    'Тип   матрицы экрана\tIPS',
#    'Частота   обновления экрана\t60 Гц',
#    'Форматы   HDR\tHDR10+',
#    'Мощность   звука\t16 Вт',
#    'Беспроводная  связь Bluetooth, Wi-Fi',
#    'Технология   экрана QLED, HDR'],
#   'is_reference': False,
#   'reference_id': '13f78f44e27fec08'},
#  {'product_id': '04f53c1522916766',
#   'name': 'ABC Посудомоечная машина Gorenje GV62040, встраиваемая, 60 см, A++, AquaStop',
#   'props': ['Таймер  отсрочки запуска\tесть',
#    'Тип\tполноразмерная',
#    'Ширина\t59.6  см',
#    'Защита\tзащита  от протечек',
#    'Вместимость\t13   комплектов',
#    'Число  программ класс мойки: A, 5',
#    'Тип  сушки класс A, конденсационная'],
#   'is_reference': False,
#   'reference_id': '856751a358b2734a'},
#  {'product_id': '0504015783019287',
#   'name': 'TP-LINK Wi-Fi роутер TP-LINK TD-W8961N',
#   'props': ['Макс. скорость беспроводного соединения 300 Мбит/с',
#    'Скорость   портов\t100 Мбит/с',
#    'Подключение  к интернету (WAN)\tADSL',
#    'Частотный  диапазон устройств Wi-Fi\t2.4 ГГц'],
#   'is_reference': False,
#   'reference_id': '78bec6b366af5726'},
#  {'product_id': '0538f0214897917f',
#   'name': 'Встраиваемая посудомоечная машина KORTING KDI 45985',
#   'props': ['Тип\tузкая',
#    'Таймер   отсрочки запуска\tесть',
#    'Тип   сушки класс A, интенсивная'],
#   'is_reference': False,
#   'reference_id': '74b8df4389f87055'},
#  {'product_id': '0544c46c585254ab',
#   'name': 'Фоторамка Hyundai HYC-0101 black enamel',
#   'props': ['Доп.   функции\tтаймер'],
#   'is_reference': False,
#   'reference_id': '3c096a1f539c1daf'},
#  {'product_id': '054f98bad135dc7f',
#   'name': 'Планшет Samsung Galaxy Tab A8 10.5 32GB LTE Grey (SM-X205)',
#   'props': ['Емкость  аккумулятора\t7040 мА·ч',
#    'Процессор\tUnisoc   Tiger T618',
#    'Экран  TFT , 60 Гц, 10.5" (1920x1200)',
#    'Размеры   вес: 508 г, 246.8x161.9x6.9 мм',
#    'Особенности  cлот для карты памяти, компас, акселерометр, датчик Холла, датчик освещенности, встроенный микрофон, гироскоп'],
#   'is_reference': False,
#   'reference_id': '2f92010236ee9319'},
#  {'product_id': '05566759a778ecce',
#   'name': 'Смартфон Xiaomi Redmi 10C NFC 4/128 ГБ RU, зеленая мята',
#   'props': ['SIM-карты\t2 (nano SIM)',
#    'Аккумулятор\t5000   мА·ч',
#    'Операционная   система\tAndroid 11',
#    'Оперативная  память\t4 ГБ',
#    'Qualcomm  Snapdragon 680',
#    'Вес\t190   г',
#    'Беспроводные   интерфейсы NFC, Wi-Fi, Bluetooth'],
#   'is_reference': False,
#   'reference_id': 'df3067c6ea1deee5'},
#  {'product_id': '0558d87aaaf9ec6b',
#   'name': 'Монитор Lenovo C24-20',
#   'props': ['Яркость\t250  кд/м²; контрастность: 1000:1',
#    'Экран\t1920x1080 (16:9)'],
#   'is_reference': False,
#   'reference_id': '8f9c8fcf9cb2862c'},
#  {'product_id': '055fc466887183f0',
#   'name': 'Видеокарта Asus TUF RTX 3060ti 8Gb',
#   'props': ['Поддержка   технологий поддержка CUDA, поддержка HDCP, поддержка Vulkan, поддержка трассировки лучей',
#    'Количество   поддерживаемых мониторов\t4',
#    'Объем  видеопамяти\t8192 МБ',
#    'Максимальное  разрешение\t7680x4320',
#    'Тип  памяти\tGDDR6',
#    'Тип   подключения\tPCI Express 4.0',
#    'Техпроцесс\t8  нм'],
#   'is_reference': False,
#   'reference_id': '108edf8f1054d7d4'},
#  {'product_id': '0568dfb9f958d011',
#   'name': 'Ноутбук Lenovo IdeaPad 3-15 / Ryzen 5 4500U / 4Gb / SSD 256Gb / AMD Radeon Graphics / 15,6 FHD IPS / BT Cam / No OS / Серый 81W40033RK',
#   'props': ['Видеокарта  встроенная, AMD Radeon Graphics'],
#   'is_reference': False,
#   'reference_id': '01378fa92f901df5'},
#  {'product_id': '056c316d8bcccf9a',
#   'name': 'Беспроводные наушники Xiaomi Air 2 SE CN, белый',
#   'props': ['Время работы\t5 ч',
#    'Тип зарядки кейса\tUSB Type-C',
#    'Импеданс\t32  Ом',
#    'Тип  излучателей\tдинамические'],
#   'is_reference': False,
#   'reference_id': '4fae4dee12611ab9'},
#  {'product_id': '05839985429a5c5a',
#   'name': 'Ноутбук Lenovo 15ACH6 82K201D1RK Ryzen 5 5600H/8ГБ/256ГБ SSD/RTX 3050 4ГБ/15.6"FHD IPS 60ГЦ/DOS',
#   'props': ['Видеопамять\t4 ГБ'],
#   'is_reference': False,
#   'reference_id': '11777853e7c22618'},
#  {'product_id': '05a6035c4df3649b',
#   'name': 'Монитор Dell 27" S2721HS',
#   'props': ['Частота  обновления\t75 Гц; отклик: 4 мс'],
#   'is_reference': False,
#   'reference_id': '443fbb7739d5eccb'},
#  {'product_id': '05a95e7066dc4c52',
#   'name': 'Умный браслет Xiaomi Mi Band 7 Global, черный',
#   'props': ['Емкость аккумулятора\t180 мА·ч',
#    'Экран\t1.62"  (192x490) AMOLED',
#    'Материал  браслета/ремешка\tтермополиуретан',
#    'Беспроводная   связь\tBluetooth',
#    'Совместимость   Android, iOS',
#    'Мониторинг   постоянное измерение пульса, измерение уровня кислорода в крови'],
#   'is_reference': True,
#   'reference_id': None},
#  {'product_id': '05b890aff0340900',
#   'name': 'Ariston водонагреватель накопительный ariston abs andris lux 6 or 1500 вт 6 л',
#   'props': ['Максимальная температура воды\t75 °С',
#    'Управление\tмеханическое',
#    'Полезная мощность\t1.5 кВт'],
#   'is_reference': False,
#   'reference_id': 'f3823ddbc3398737'},
#  {'product_id': '05c3959e79069d8a',
#   'name': 'Ноутбук LENOVO V15-ADA (Ryzen 5 3500U 8Gb SSD256Gb/AMD Radeon /15.6 TN/FHD (1920x1080) NoOS. grey)(82C7000YRU)',
#   'props': ['Время  работы от аккумулятора\t6 ч'],
#   'is_reference': False,
#   'reference_id': '2ce6f8d283aa69c5'},
#  {'product_id': '05cb692a7fd6c0e6',
#   'name': 'Компьютерная акустика Defender SPK 33',
#   'props': ['Материал корпуса колонок',
#    'пластик',
#    'Компьютерная акустика 2.0',
#    'Суммарная мощность 5 Вт',
#    'Диапазон частот 100 - 20000 Гц',
#    'Однополосные  колонки',
#    'Питание   от USB'],
#   'is_reference': True,
#   'reference_id': None},
#  {'product_id': '05d0ee8f37865ec8',
#   'name': 'LG MW-23R35GIB Микроволновая печь',
#   'props': ['Объем\t23 л',
#    'Переключатели\tсенсорные',
#    'ШхВхГ\t47.60х27.20х35.70 см',
#    'Доп. режимы звуковой сигнал отключения, автоматическое приготовление, автоматическая разморозка',
#    'Мощность  микроволн\t1000 Вт',
#    'Инверторное   управление мощностью\tда',
#    'Особенности   блокировка от детей, дисплей, система равномерного распределения микроволн, подсветка камеры'],
#   'is_reference': False,
#   'reference_id': 'd5f74488ca1cd971'},
#  {'product_id': '05d4f6d7e4fe8c4b',
#   'name': 'Умные часы Samsung Galaxy Watch4 40 мм Wi-Fi NFC, черный',
#   'props': ['Материал браслета/ремешка\tэластомер',
#    'Защищенность\tвлагозащита',
#    'Совместимость\tAndroid',
#    'Экран\t1.2"  (396x396) Super AMOLED',
#    'Материал  корпуса\tалюминий',
#    'Емкость  аккумулятора\t247 мА·ч',
#    'Операционная   система\tWear OS',
#    'Беспроводная   связь Beidou, Galileo, NFC, вывод аудио на Bluetooth-устройства, ГЛОНАСC, Bluetooth, Wi-Fi, GPS',
#    'Мониторинг   постоянное измерение пульса, акселерометр, измерение уровня кислорода в крови, ЭКГ, тонометр, мониторинг сна, мониторинг физической активности, мониторинг калорий'],
#   'is_reference': True,
#   'reference_id': None},
#  {'product_id': '05e4faa8c8de9ce1',
#   'name': 'Микроволновая печь Samsung MS23K3614AW, белый',
#   'props': ['Режимы работы\tразморозка',
#    'Переключатели\tповоротные   тактовые',
#    'Объем\t23  л'],
#   'is_reference': False,
#   'reference_id': 'bd828d1ddcec8c48'},
#  {'product_id': '060446776e81bff7',
#   'name': 'Роутер D-link DIR-620S/RU/B1A',
#   'props': ['Макс.  скорость беспроводного соединения 300 Мбит/с',
#    'Подключение к интернету (WAN) внешний модем, Ethernet RJ-45'],
#   'is_reference': False,
#   'reference_id': '1eca353c3aaa0108'},
#  {'product_id': '0607c04000d78548',
#   'name': 'МФУ лазерное Canon i-SENSYS MF3010',
#   'props': ['Макс. формат печати\tA4 (210 × 297 мм)',
#    'Интерфейсы\tUSB',
#    'Функции копирование, сканирование, отправка изображения по e-mail',
#    'Печать\tчерно-белая   лазерная',
#    'Назначение   для дома, небольшого офиса'],
#   'is_reference': True,
#   'reference_id': None},
#  {'product_id': '06104ddeb1607bbb',
#   'name': 'Процессор AMD Ryzen 9 5950X AM4 (100-000000059) (3.4GHz) OEM',
#   'props': ['Техпроцесс\t7 нм',
#    'Дата выхода\tQ4 2020',
#    'Сокет  AM4',
#    'Ядро   процессора Vermeer',
#    'Назначение  настольный ПК, игровой'],
#   'is_reference': False,
#   'reference_id': 'f1ef51ca6bab03d3'},
#  {'product_id': '06407be35728ffb5',
#   'name': 'Встраиваемая стиральная машина Indesit BI WMIL 71252',
#   'props': ['Загрузка\t7 кг',
#    'Дозагрузка белья\tчерез основной люк',
#    'Установка\tвстраиваемая',
#    'Класс энергопотребления\tA++',
#    'Доп.функции контроль баланса, выбор температуры стирки, контроль за уровнем пены, интеллектуальное управление стиркой, отложенный старт, выбор скорости отжима',
#    'ШхГхВ\t60х54х82  см'],
#   'is_reference': False,
#   'reference_id': 'e5542a95bc882c43'},
#  {'product_id': '0651ae84260cc330',
#   'name': 'Робот-пылесос Xiaomi Viomi Vacuum Cleaning Robot V3 black',
#   'props': ['Объем  контейнера для пыли\t0.55 л'],
#   'is_reference': False,
#   'reference_id': '1c370548bdb8590d'},
#  {'product_id': '06746b7db596bcf8',
#   'name': 'BEKO DIS 25010',
#   'props': ['Вместимость\t10 комплектов',
#    'Индикация  на полу\tлуч',
#    'Ширина\t44.8  см'],
#   'is_reference': False,
#   'reference_id': '193e2a2bb43ac363'},
#  {'product_id': '068fa69c1446a046',
#   'name': 'Кондиционер Electrolux EACS-09HAT/N3',
#   'props': ['Фильтры\tдезодорирующий',
#    'Класс энергоэффективности\tA',
#    'Режим  работы\tохлаждение / обогрев',
#    'Площадь   помещения\t25 м²',
#    'Мощность  охлаждения\t2640 Вт / обогрева: 2780 Вт',
#    'Доп.   режимы осушение, вентиляция, ночной'],
#   'is_reference': False,
#   'reference_id': 'f3e10061c5a04f2c'},
#  {'product_id': '06a63d37a344489f',
#   'name': 'Колонки Defender SPK-33 питание от usb, 5 Вт',
#   'props': ['Материал  корпуса колонок'],
#   'is_reference': False,
#   'reference_id': '05cb692a7fd6c0e6'},
#  {'product_id': '06ac8bfc298c9b1b',
#   'name': 'Монитор Lenovo S22e-20',
#   'props': ['Покрытие  экрана матовое, антибликовое'],
#   'is_reference': False,
#   'reference_id': '73c8a97445f43966'},
#  {'product_id': '06cf3e4f54402e5e',
#   'name': 'Телевизор Xiaomi Mi TV 65" L65M5-5ASP',
#   'props': ['Разрешение\t3840x2160', 'Беспроводная  связь Bluetooth, Wi-Fi'],
#   'is_reference': False,
#   'reference_id': '1253c3296a3c0153'},
#  {'product_id': '06db57f6264dd195',
#   'name': 'Смартфон Xiaomi Redmi Note 11 Pro 128Gb 8Gb голубой моноблок 3G 4G 2Sim 6.67" 1080x2400 Android 11 108Mpix 802.11 a/b/g/n/',
#   'props': ['Оперативная память\t8 ГБ',
#    'Аккумулятор\t5000 мА·ч',
#    'SIM-карты\t2 (nano SIM)',
#    '4 камеры 2 МП, 2 МП, 108 МП, 8 МП',
#    'Встроенная   память\t128 ГБ',
#    'MediaTek   Helio G96',
#    'Операционная  система\tAndroid 11'],
#   'is_reference': False,
#   'reference_id': 'abe138723279f9af'},
#  {'product_id': '06e0e1fda9b32fc2',
#   'name': 'МФУ Pantum M6507W A4, 1200x1200 dpi, ч/б 22 стр/мин (А4), Wi-Fi, USB',
#   'props': ['ЖК-панель\tда',
#    'Назначение\tдля  небольшого офиса',
#    'Функции сканирование, отправка изображения по e-mail, копирование'],
#   'is_reference': False,
#   'reference_id': 'f90d8061194fbf26'},
#  {'product_id': '070ac4bba6913891',
#   'name': 'Монитор Samsung 27" S27R356FHI темно-серый IPS LED 16:9 HDMI Mat 250cd',
#   'props': ['Частота  обновления\t75 Гц; отклик: 5 мс'],
#   'is_reference': False,
#   'reference_id': 'e8ca5c0eeaa7f392'},
#  {'product_id': '070dc176903f03f4',
#   'name': 'Thermex iu 30',
#   'props': ['Управление\tмеханическое',
#    'Полезная   мощность\t2 кВт',
#    'Размеры   (ШxВxГ)\t270x800x285 мм',
#    'Потребляемая  мощность\t2000 Вт',
#    'Покрытие   бака\tнерж.сталь',
#    'Системы  защиты обратный клапан, предохранительный клапан'],
#   'is_reference': False,
#   'reference_id': 'fee1d1dc53f135d1'},
#  {'product_id': '070dd48327cad4d5',
#   'name': 'Микроволновая печь LG MS2535GIS, черный',
#   'props': ['Объем\t25 л',
#    'Инверторное управление мощностью\tда',
#    'Внутреннее покрытие камеры\tэмаль',
#    'Переключатели\tсенсорные',
#    'Мощность  микроволн\t1000 Вт',
#    'Диаметр  поддона\t292 мм',
#    'Режимы   работы\tразморозка',
#    'ШхВхГ\t47.60х27.20х36.80   см',
#    'Особенности   подсветка камеры, дисплей, блокировка от детей',
#    'Доп.  режимы автоматический разогрев, программирование процесса приготовления, звуковой сигнал отключения, автоматическое поддержание температуры, автоматическое приготовление, автоматическая разморозка'],
#   'is_reference': True,
#   'reference_id': None},
#  {'product_id': '071c3912b1f11dd9',
#   'name': 'Колонка компьютерная 2.0 Defender, SPK 33, пластик, USB, AUX, MP3, цвет: серый',
#   'props': ['Материал корпуса колонок',
#    'пластик',
#    'Суммарная   мощность 5 Вт',
#    'Питание  от USB'],
#   'is_reference': False,
#   'reference_id': '05cb692a7fd6c0e6'},
#  {'product_id': '072c638be843600e',
#   'name': 'Фен для волос Braun HD130 1200Вт черный',
#   'props': ['Число   режимов нагрева\t2'],
#   'is_reference': False,
#   'reference_id': '81bfaff4d9a7c386'},
#  {'product_id': '0732e613991559a7',
#   'name': 'Видеокарта GIGABYTE Radeon RX 6750 XT GAMING OC 12G (GV-R675XTGAMING OC-12GD)',
#   'props': ['Шина  обмена с памятью\t192 бит', 'Объем  видеопамяти\t12288 МБ'],
#   'is_reference': False,
#   'reference_id': 'a07d5538ebec8e36'},
#  {'product_id': '0757e67c4ab08bc6',
#   'name': 'Встраиваемая стиральная машина KRONA KAYA 1200 7K WHITE (KRWM107)',
#   'props': ['Скорость   отжима\t1200 об/мин',
#    'Класс   энергопотребления\tA++',
#    'Загрузка\t7  кг',
#    'Доп.функции   выбор скорости отжима, контроль за уровнем пены, выбор температуры стирки, отложенный старт, контроль баланса'],
#   'is_reference': False,
#   'reference_id': '94e5f00c4138bbf8'},
#  {'product_id': '07595834e2ac11c2',
#   'name': 'MARTA MT-4210 черный жемчуг электроплитка',
#   'props': ['Управление\tэлектронное',
#    'ШхВхГ\t29.50х5х36 см',
#    'Макс.  потребляемая мощность\t2000 Вт'],
#   'is_reference': False,
#   'reference_id': '47355d644fa375b2'},
#  {'product_id': '0793124d86c65dc5',
#   'name': 'Холодильник NORDFROST NRB 152 032, белый',
#   'props': ['ШхВхГ 57х188х62 см',
#    'Общий объем 320 л',
#    'Объем холодильной камеры 205 л',
#    'Объем морозильной камеры 115 л',
#    'Размораживание   морозильной камеры ручное',
#    'Размораживание  холодильной камеры капельная система',
#    'Класс  энергопотребления A+',
#    'Тип   компрессора стандартный',
#    'Мощность  замораживания 4.5 кг/сутки',
#    'Особенности   конструкции перевешиваемые двери, антибактериальное покрытие'],
#   'is_reference': True,
#   'reference_id': None},
#  {'product_id': '07932e90ebf30d79',
#   'name': 'Сплит-система Electrolux EACS-09HF/N3_22Y',
#   'props': ['Линейка\tFusion   Ultra'],
#   'is_reference': False,
#   'reference_id': '2fb0f64b2f454ce5'},
#  {'product_id': '079b45147aa03ea4',
#   'name': 'Фен домашний Lumme LU-1057',
#   'props': ['Насадки\tконцентратор', 'Вес\t350   г'],
#   'is_reference': False,
#   'reference_id': '7bd6e22a9ae5875a'},
#  {'product_id': '07b94cbea775b180',
#   'name': 'Процессор Amd Процессор AMD FX-4350 OEM',
#   'props': ['Количество ядер\t4 x 4200 МГц', 'Ядро   процессора Vishera'],
#   'is_reference': False,
#   'reference_id': '6a8af20af594f8f6'},
#  {'product_id': '07be2569f73bd6b7',
#   'name': 'Сплит-система Zanussi ZACS-09 HPR/A18/N1, белый',
#   'props': ['Доп. режимы турбо, ночной, осушение, вентиляция',
#    'Площадь   помещения\t25 м²',
#    'Мощность  кондиционера\t9 BTU',
#    'Режим   работы\tохлаждение / обогрев',
#    'Мощность  охлаждения\t2700 Вт / обогрева: 2800 Вт',
#    'Класс   энергоэффективности\tA',
#    'Особенности   пульт ДУ, таймер включения/выключения, регулировка направления воздушного потока, дисплей',
#    'Уровень  шума внутреннего блока\t24 дБ'],
#   'is_reference': True,
#   'reference_id': None},
#  {'product_id': '07d12ec5a962c925',
#   'name': 'Микроволновая печь LG MB65R95DIS, черный',
#   'props': ['Объем\t25 л',
#    'Инверторное управление мощностью\tда',
#    'Внутреннее покрытие камеры\tэмаль',
#    'Диаметр поддона\t292 мм',
#    'Переключатели\tсенсорные',
#    'ШхВхГ\t47.60х27.20х38 см',
#    'Режимы работы гриль, разморозка, микроволны + гриль',
#    'Особенности система равномерного распределения микроволн, блокировка от детей, подсветка камеры, дисплей',
#    'Мощность   микроволн\t1000 Вт',
#    'Доп.  режимы автоматическая разморозка, автоматическое приготовление, звуковой сигнал отключения'],
#   'is_reference': True,
#   'reference_id': None},
#  {'product_id': '07d75a993b4cb8ef',
#   'name': 'XIAOMI Смартфон Xiaomi Redmi Note 10S 6/128GB (NFC), белый',
#   'props': ['MediaTek Helio G95',
#    'Вес\t179 г',
#    'Экран\t6.43"  (2400x1080) AMOLED 60 Гц',
#    'Аккумулятор\t5000   мА·ч',
#    'Степень  защиты\tIP53',
#    'Оперативная   память\t6 ГБ',
#    '4  камеры 64 МП, 2 МП, 2 МП, 8 МП',
#    'Беспроводные  интерфейсы инфракрасный порт (IRDA), NFC, Bluetooth, Wi-Fi',
#    'Стандарт   связи 4G LTE, 2G, 3G'],
#   'is_reference': False,
#   'reference_id': '000740b6c1cc763e'},
#  {'product_id': '07dd1a05a5cb1469',
#   'name': 'Электроплитка Energy EN-904B черная 2-х конфорочная (спиральный ТЭН) 1.0 кВт, 140мм (158967)',
#   'props': ['Настольная\tда'],
#   'is_reference': False,
#   'reference_id': '6ba3b74a1ca138cf'},
#  {'product_id': '07e20f55ecde560e',
#   'name': 'Ноутбук ASUS S15 S533EA-BN410W i5-1135G7/16GB/512GB SSD/15.6" FHD IPS/Win11 Black (90NB0SF3-M002P0)',
#   'props': ['Память   RAM 16 ГБ, SSD 512 ГБ',
#    'Видеокарта  Intel Iris Xe Graphics, встроенная'],
#   'is_reference': False,
#   'reference_id': 'e62b831e32efcbc8'},
#  {'product_id': '07fad58bc62358d6',
#   'name': 'Процессор Intel Core i5-11400F CM8070804497016 Rocket Lake 6C/12T 2.6-4.4GHz (LGA1200, L3 12MB, 14nm, 65W)',
#   'props': ['Ядро процессора Rocket Lake-S',
#    'Тепловыделение 65 Вт',
#    'Техпроцесс\t14 нм',
#    'Количество  потоков\t12',
#    'Оперативная  память\t2 x DDR4 3200 МГц'],
#   'is_reference': False,
#   'reference_id': '18a5d547a136f872'},
#  {'product_id': '0800e543055cd752',
#   'name': 'Процессор Intel CPU Core i9-12900KF',
#   'props': ['Количество ядер\t16 x 3200-5200 МГц',
#    'Количество  потоков\t24',
#    'Сокет  LGA1700',
#    'Назначение  игровой, настольный ПК',
#    'Оперативная  память DDR5 3200/4800 МГц, 2 x DDR4'],
#   'is_reference': False,
#   'reference_id': '1d56acfbc4983b65'},
#  {'product_id': '081566c0d3907412',
#   'name': 'Телевизор LED 50" SAMSUNG QE50Q60ABUXRU',
#   'props': ['Разрешение\t3840x2160',
#    'Тип подсветки\tDual LED',
#    'Платформа  Smart TV\tTizen',
#    'Частота   обновления экрана\t60 Гц',
#    'Год  создания модели\t2021',
#    'Разъемы  и интерфейсы USB Type-A x 2, Ethernet - RJ-45, вход HDMI x 3, слот CI/CI+, выход аудио оптический',
#    'Беспроводная  связь Bluetooth, Wi-Fi'],
#   'is_reference': False,
#   'reference_id': '7daa2feb09ae2f1b'},
#  {'product_id': '082029f03b15fb85',
#   'name': 'Робот-пылесос Xiaomi Mi Robot Vacuum Mop 2 Pro White MJST1SHW',
#   'props': ['Тип уборки\tсухая и влажная',
#    'Объем контейнера для пыли\t0.45 л',
#    'ШхГхВ\t35.30x35.30x9.65  см',
#    'Тип   контейнера\tдля пыли/воды',
#    'Режимы  работы местная уборка, движение вдоль стен',
#    'Доп. функции программирование по дням недели, таймер, построение карты помещения'],
#   'is_reference': False,
#   'reference_id': '516c4c0cca619ea4'},
#  {'product_id': '08392f9f9bc7c1c8',
#   'name': 'Встраиваемая стиральная машина Bosch WIW 28540 OE',
#   'props': ['Класс энергопотребления\tA+++',
#    'Скорость   отжима\t1400 об/мин',
#    'Загрузка\t8   кг',
#    'Доп.функции сигнал окончания стирки, выбор скорости отжима, контроль за уровнем пены, контроль баланса, отложенный старт, интеллектуальное управление стиркой, выбор температуры стирки'],
#   'is_reference': False,
#   'reference_id': 'b74de9b0b28590b4'},
#  {'product_id': '08516de8de755f62',
#   'name': 'МФУ лазерное Canon i-SENSYS MF443dw',
#   'props': ['Макс. размер отпечатка\t216 × 356 мм',
#    'Особенности\tавтоматическая двусторонняя печать',
#    'Назначение\tдля  среднего офиса',
#    'Печать\tчерно-белая  лазерная',
#    'Макс.  формат печати\tA4 (210 × 297 мм)',
#    'Цветной   ЖК-дисплей\tда',
#    'Функции   сканирование, отправка изображения по e-mail, копирование',
#    'Интерфейсы  Wi-Fi, USB, Ethernet (RJ-45), AirPrint'],
#   'is_reference': True,
#   'reference_id': None},
#  {'product_id': '086a5de0723424e7',
#   'name': 'Микроволновая Печь Samsung MG23T5018AP/BW 23л. 800Вт розовый',
#   'props': ['Диаметр поддона\t288 мм',
#    'Мощность микроволн\t800 Вт',
#    'Доп. режимы ускоренная разморозка, автоматическое приготовление, автоматическая разморозка, звуковой сигнал отключения',
#    'Режимы работы разморозка, микроволны + гриль, гриль'],
#   'is_reference': False,
#   'reference_id': '8b3925c2f2a210c5'},
#  {'product_id': '087ab5b24f315e87',
#   'name': 'Apple Watch Series 7 Apple Часы Apple Watch Series 7 41mm Aluminum Case with Sport Band Global, сияющая звезда',
#   'props': ['Операционная   система\tWatch OS',
#    'Материал   браслета/ремешка\tсиликон',
#    'Размер ремешка\tR',
#    'Совместимость\tiOS'],
#   'is_reference': False,
#   'reference_id': '54f50670bcf48f9a'},
# ...
#  {'product_id': '4a831a08c888ce31',
#   'name': 'Накопительный электрический водонагреватель thermex ic 10 u inox cask (белый)',
#   'props': ['Системы   защиты предохранительный клапан, от перегрева',
#    'Потребляемая мощность\t1500 Вт',
#    'Максимальная температура воды\t75 °С',
#    "Установка\tвертикальная   на стену с верхней подводкой (½')",
#    'Время   нагрева\t28 мин'],
#   'is_reference': False,
#   'reference_id': 'd4fe7179ce05fe85'},
#  {'product_id': '4a9d1db866b8666e',
#   'name': 'Ноутбук Honor MagicBook 16 R5/16/512 Grey (HYM-W56) 5301ABCM',
#   'props': ['Процессор\tAMD   Ryzen 5 5600H (6x3.30 ГГц)'],
#   'is_reference': False,
#   'reference_id': '15cb3a27705c8a79'},
#  {'product_id': '4aa7a92238a6b9f9',
#   'name': 'Монитор Xiaomi Mi Curved Gaming Monitor 34 (XMMNTWQ34)',
#   'props': ['Покрытие экрана\tантибликовое',
#    'Игровой   монитор\tда',
#    'Частота  обновления\t144 Гц; отклик: 4 мс',
#    'Яркость\t300   кд/м²; контрастность: 3000:1',
#    'Интерфейсы  вход DisplayPort x 2, вход HDMI x 2'],
#   'is_reference': False,
#   'reference_id': 'eab61e20ff52459e'},
#  {'product_id': '4ab004bd3c60bab9',
#   'name': "Кофемашина капсульная De'Longhi Nespresso Inissia EN 80",
#   'props': ['Тип используемого кофе\tкапсулы',
#    'Тип капсул\tNespresso Original',
#    'Настройки\tобъем порции горячей воды',
#    'Тип  напитка эспрессо, капучино, латте макиато, лунго',
#    'Доп.  функции\tавтоотключение при неиспользовании',
#    'Материал   корпуса\tпластик',
#    'Особенности  конструкции индикатор включения, съемный лоток для сбора капель, индикатор уровня воды, контейнер для отходов'],
#   'is_reference': True,
#   'reference_id': None},
#  {'product_id': '4ab0fe10a0578149',
#   'name': 'Смарт-часы Xiaomi Mi Watch Navy Blue, син, BHR4583GL, 1 шт.',
#   'props': ['Беспроводная связь GPS, Galileo, Bluetooth, Beidou, ГЛОНАСC',
#    'Мониторинг акселерометр, мониторинг сна, мониторинг физической активности, мониторинг калорий, измерение уровня кислорода в крови, постоянное измерение пульса',
#    'Емкость  аккумулятора\t420 мА·ч'],
#   'is_reference': False,
#   'reference_id': 'fb35f7fa64691535'},
#  {'product_id': '4ab90a2d503df5ee',
#   'name': 'Накопительный водонагреватель термекс titaniumheat 150 v (445х459х1283) 150л, 1,5квт, биостеклоф',
#   'props': ['Размеры (ШxВxГ)\t445x1283x459 мм',
#    'Полезная мощность\t1.5 кВт',
#    'Управление\tмеханическое',
#    'Индикация включения, нагрева',
#    'Максимальная  температура воды\t75 °С',
#    'Покрытие   бака\tстеклокерамика',
#    "Установка\tвертикальная  на стену с нижней подводкой (½')"],
#   'is_reference': False,
#   'reference_id': '3506a28b65ac9e2b'},
#  {'product_id': '4acad6dbbcdb3793',
#   'name': 'Фен PHILIPS BHD360/20 black (BHD360/20)',
#   'props': ['Мощность\t2100  Вт'],
#   'is_reference': False,
#   'reference_id': '471b8b5f9c648910'},
#  {'product_id': '4acfce79352a2f23',
#   'name': 'П/м Gorenje GV62040',
#   'props': ['Тип\tполноразмерная',
#    'Ширина\t59.6  см',
#    'Таймер   отсрочки запуска\tесть',
#    'Защита\tзащита  от протечек'],
#   'is_reference': False,
#   'reference_id': '856751a358b2734a'},
#  {'product_id': '4ad6223da8220196',
#   'name': 'Фен Braun Satin Hair 1 Style&Go HD130',
#   'props': ['Число режимов нагрева\t2', 'Насадки\tконцентратор'],
#   'is_reference': False,
#   'reference_id': '81bfaff4d9a7c386'},
#  {'product_id': '4aeabff2659f23f1',
#   'name': 'Процессор Intel Core i3-10100F CM8070104291318 Comet Lake-S 4C/8T 3.6/4.3GHz (LGA1200, DMI 8GT/s, L3 6MB, 14nm, 65W) OEM',
#   'props': ['Назначение  настольный ПК, игровой'],
#   'is_reference': False,
#   'reference_id': '377541fb839e74c8'},
#  {'product_id': '4af396d80ca1d0f0',
#   'name': 'Видеокарта Gigabyte PCI-E 4.0 GV-R675XTGAMING OC-12GD AMD Radeon RX 6750XT 12288Mb 192 GDDR6 2514/16000 HDMIx2 DPx2 HDCP Ret',
#   'props': ['Максимальное  разрешение\t7680x4320'],
#   'is_reference': False,
#   'reference_id': 'a07d5538ebec8e36'},
#  {'product_id': '4af58adbc2dc4e88',
#   'name': 'Акустическая система Defender 2.0 SPK-190 8Вт с питанием от USB для PC (черный)',
#   'props': ['Компьютерная акустика 2.0',
#    'пластик',
#    'Разъем  для наушников',
#    'Питание   от USB',
#    'Материал   корпуса колонок'],
#   'is_reference': False,
#   'reference_id': 'e256cd9888e0f207'},
#  {'product_id': '4b220b0b1cabd51a',
#   'name': 'Стиральная машина Kuppersberg WM 1477, белый',
#   'props': ['Установка\tвстраиваемая',
#    'Защита от протечек, от детей',
#    'Загрузка\t7   кг',
#    'ШхГхВ\t59.60х54х82   см',
#    'Скорость   отжима\t1400 об/мин',
#    'Класс  энергопотребления\tA++',
#    'Особенности  конструкции\tотсек для жидкого порошка',
#    'Доп.функции   выбор температуры стирки, выбор скорости отжима, сигнал окончания стирки, контроль баланса, интеллектуальное управление стиркой, отложенный старт, контроль за уровнем пены, установка времени завершения стирки'],
#   'is_reference': True,
#   'reference_id': None},
#  {'product_id': '4b59cf0aad60dfe4',
#   'name': 'Микроволновая печь Whirlpool MAX 45 FW S, белый',
#   'props': ['Диаметр поддона\t280 мм',
#    'Переключатели\tсенсорные',
#    'ШхВхГ\t39.20х36х35.30 см',
#    'Доп. режимы автоматическая разморозка, автоматический разогрев, автоматическое приготовление, звуковой сигнал отключения',
#    'Особенности программирование рецептов в память, система равномерного распределения микроволн, дисплей, подсветка камеры, блокировка от детей',
#    'Объем\t13  л',
#    'Мощность   микроволн\t700 Вт',
#    'Внутреннее   покрытие камеры\tэмаль',
#    'Режимы  работы\tразморозка'],
#   'is_reference': True,
#   'reference_id': None},
#  {'product_id': '4b64f2256bb9afdf',
#   'name': 'Процессор Intel CORE I5-12600KF S1700 OEM 3.7G CM8071504555228 S RL4U IN',
#   'props': ['Сокет LGA1700',
#    'Количество потоков\t16',
#    'Количество ядер\t10 x 3700-4900 МГц',
#    'Назначение настольный ПК, игровой'],
#   'is_reference': False,
#   'reference_id': 'fc0a307822fa30f3'},
#  {'product_id': '4b808f251cbe0e54',
#   'name': 'Монитор 19,5" Lenovo ThinkVision E20-20 62BBKAT1EU 1440x900, IPS, 4ms, 1000:1, 16:10, 250cd/m2, 178/178, HDMI, VGA, Tilt, raven black',
#   'props': ['Интерфейсы видео вход VGA, вход HDMI', 'Цвет   товара\tчерный'],
#   'is_reference': False,
#   'reference_id': '647995c157f7d99a'},
#  {'product_id': '4b80f37d12957027',
#   'name': 'Монитор Lenovo 23,8" C24-20 (62A8KAT1EU)',
#   'props': ['Яркость\t250  кд/м²; контрастность: 1000:1',
#    'Интерфейсы  вход VGA, вход HDMI'],
#   'is_reference': False,
#   'reference_id': '8f9c8fcf9cb2862c'},
#  {'product_id': '4b821637711ff59f',
#   'name': 'Водонагреватель газовый проточный bosch therm 4000 o wr10-2 p23 s5795',
#   'props': ["Установка\tвертикальная на стену с нижней подводкой (½')",
#    'Полезная мощность\t17.4 кВт',
#    'Системы защиты газ-контроль, от перегрева',
#    'Потребляемая   мощность\t20 Вт'],
#   'is_reference': False,
#   'reference_id': '6d65b7363fdef730'},
#  {'product_id': '4b8b69e9504f701b',
#   'name': 'Samsung A336 Black 128GB',
#   'props': ['Операционная   система\tAndroid 12'],
#   'is_reference': False,
#   'reference_id': '161fca3b6bcf5fcc'},
#  {'product_id': '4bb475b2186a9554',
#   'name': 'Холодильник Whirlpool WTNF 902 M',
#   'props': ['Размораживание No Frost',
#    'Класс   энергопотребления A',
#    'Общий   объем 322 л',
#    'Объем  морозильной камеры 75 л',
#    'Объем  холодильной камеры 247 л',
#    'Режимы  суперзаморозка'],
#   'is_reference': False,
#   'reference_id': 'f440de22d764b2a3'},
#  {'product_id': '4bc3bf35b42b14b2',
#   'name': 'Стиральная машина Bosch WIW 28541',
#   'props': ['Цвет\tбелый'],
#   'is_reference': False,
#   'reference_id': '3914651e72846423'},
#  {'product_id': '4bd6ea810aa31e40',
#   'name': 'Беспроводные наушники Xiaomi Redmi Buds 3 Pro Grey (BHR5311GL)',
#   'props': ['Вес\t55 г', 'Диапазон   воспроизводимых частот\t20-20000 Гц'],
#   'is_reference': False,
#   'reference_id': '7f0e67ce52682515'},
#  {'product_id': '4bdecd6785970f05',
#   'name': 'Компьютерная акустика OKLICK OK-163',
#   'props': ['Материал корпуса колонок',
#    'MDF',
#    'Суммарная  мощность 6 Вт',
#    'Однополосные  колонки',
#    'Питание   от USB',
#    'Диапазон  частот 150 - 18000 Гц',
#    'Компьютерная   акустика 2.0'],
#   'is_reference': True,
#   'reference_id': None},
#  {'product_id': '4c0ac9ff8c63b399',
#   'name': 'GIGABYTE GeForce RTX 3080 GAMING OC 12G, GV-N3080GAMING OC-12GD, Retail',
#   'props': ['Поддержка  технологий поддержка HDCP, поддержка CUDA, поддержка трассировки лучей, поддержка Vulkan',
#    'Частота памяти\t19000 МГц',
#    'Тип памяти\tGDDR6X',
#    'Количество поддерживаемых мониторов\t4',
#    'Комплектация\tRetail',
#    'Разъем дополнительного питания\t8 pin + 8 pin',
#    'Шина  обмена с памятью\t384 бит',
#    'Максимальное  разрешение\t7680x4320',
#    'Тип  подключения\tPCI Express 4.0',
#    'Область   применения\tигровая',
#    'TDP\t350   Вт',
#    'Разъемы  и интерфейсы выход HDMI, выход DisplayPort x 3'],
#   'is_reference': False,
#   'reference_id': '9158a4c6707ede74'},
#  {'product_id': '4c323f572cc2f1ec',
#   'name': 'Saeco Кофемашина Saeco Lirika Black',
#   'props': ['Приготовление капучино\tручное', 'Давление   помпы\t15 бар'],
#   'is_reference': False,
#   'reference_id': '9317f988ff2328d5'},
#  {'product_id': '4c44d7f99d4f224f',
#   'name': 'Телевизор Xiaomi Mi TV E65S Pro 65"',
#   'props': ['Форматы  HDR\tHDR10',
#    'Тип   подсветки\tDirect LED',
#    'Платформа  Smart TV\tAndroid',
#    'Мощность   звука\t16 Вт',
#    'Разрешение  HD\t4K UHD',
#    'Беспроводная   связь Bluetooth, Wi-Fi',
#    'Разъемы   и интерфейсы Ethernet - RJ-45, USB Type-A x 2, слот CI/CI+, AV-вход, вход HDMI x 3'],
#   'is_reference': False,
#   'reference_id': '8abff1fd30760f44'},
#  {'product_id': '4c483c49fc215f54',
#   'name': 'Маршрутизатор беспроводной D-Link DIR-825/RU/I1A черный',
#   'props': ['Макс. скорость беспроводного соединения 867 Мбит/с',
#    'Количество LAN-портов 4',
#    'Встроенная  поддержка SIM-карт\t3G',
#    'Функции   и особенности WDS, поддержка IPv6',
#    'Стандарт Wi-Fi 802.11 ac (Wi-Fi 5), n (Wi-Fi 4)'],
#   'is_reference': False,
#   'reference_id': 'ef7e9ae5c1c2b654'},
#  {'product_id': '4c79baeeaaeb487d',
#   'name': 'Умные часы HUAWEI 55026974',
#   'props': ['Экран\t1.43" (466x466) AMOLED',
#    'Материал  браслета/ремешка\tкаучук',
#    'Беспроводная  связь GPS, ГЛОНАСC, Bluetooth',
#    'Материал   корпуса нерж. сталь, пластик'],
#   'is_reference': False,
#   'reference_id': 'f5cbd4fcc8474730'},
#  {'product_id': '4c8a5b8f228eaed8',
#   'name': 'Планшет Lenovo Tab K10 TB-X6C6X (2021), 4 ГБ/64 ГБ, Wi-Fi + Cellular, Abyss blue',
#   'props': ['Экран 10.3" (1920x1200), IPS',
#    'Процессор\tMediaTek   Helio P22T',
#    'Операционная  система\tAndroid 11',
#    'Камеры  основная 8 МП, фронтальная 5 МП',
#    'Размеры   вес: 460 г, 244.8x153.9x8.15 мм',
#    'Особенности  акселерометр, датчик Холла, встроенный микрофон, разъем для микрофона, FM-тюнер, компас, датчик приближения, cлот для карты памяти, гироскоп, датчик освещенности'],
#   'is_reference': True,
#   'reference_id': None},
#  {'product_id': '4c8d1994bec13cd9',
#   'name': 'HP LaserJet P M404dn Принтер W1A53A',
#   'props': ['ЖК-панель\tда', 'Печать\tчерно-белая  лазерная'],
#   'is_reference': False,
#   'reference_id': 'de666c1df1cfda43'},
#  {'product_id': '4c919b51681fb20f',
#   'name': 'Ноутбук Honor MagicBook 16 HYM-W56 (AMD Ryzen 5 5600H 3200 Mhz/16.1"/1920х1080/16Gb/512Gb SSD/AMD Radeon/Windows 11 Home) 5301ABCM Космический Серый',
#   'props': ['Операционная система\tWindows 11 Home',
#    'Процессор\tAMD  Ryzen 5 5600H (6x3.30 ГГц)'],
#   'is_reference': False,
#   'reference_id': '15cb3a27705c8a79'},
#  {'product_id': '4c99fabe289a8939',
#   'name': 'Роутер беспроводной D-Link DIR-825/RU/I1A 10/100/1000BASE-TX/4G ready',
#   'props': ['Встроенная поддержка SIM-карт\t3G',
#    'Стандарт Wi-Fi 802.11 n (Wi-Fi 4), ac (Wi-Fi 5)',
#    'Макс.   скорость беспроводного соединения 867 Мбит/с',
#    'Цвет  товара\tчерный'],
#   'is_reference': False,
#   'reference_id': 'ef7e9ae5c1c2b654'},
#  {'product_id': '4cb28cfe72a077d5',
#   'name': 'Сплит-система General Climate GC-RE09HR/GU-RE09H Pulsar Inverter',
#   'props': ['Доп. режимы вентиляция, осушение'],
#   'is_reference': False,
#   'reference_id': '4f9bf73be63fa349'},
#  {'product_id': '4cdf2d242e632db4',
#   'name': 'Газовая плита GEFEST 700-02 (коричневый)',
#   'props': ['Возможность   подключения к газовому баллону\tесть',
#    'Настольная\tда',
#    'Управление\tмеханическое'],
#   'is_reference': False,
#   'reference_id': '116c9e6140857b4b'},
#  {'product_id': '4ce12b22a6dfed7a',
#   'name': 'Mi Robot Vacuum-Mop 2 Pro EU White',
#   'props': ['Тип   контейнера\tдля пыли/воды',
#    'Комплектация\tбоковая   щетка',
#    'Работа   от аккумулятора\tдо 110 мин',
#    'Особенности  конструкции\tмягкий бампер',
#    'Тип  уборки\tсухая и влажная',
#    'Тип   датчиков\tоптические'],
#   'is_reference': False,
#   'reference_id': '516c4c0cca619ea4'},
#  {'product_id': '4ce94df2da952a2d',
#   'name': 'Кондиционер Jax ACN-09 HE Tasmania',
#   'props': ['Фильтры\tдезодорирующий',
#    'Уровень шума внутреннего блока\t23 дБ - 35 дБ',
#    'Особенности таймер включения/выключения, регулировка направления воздушного потока, дисплей, пульт ДУ'],
#   'is_reference': False,
#   'reference_id': '664b48a4aafdf9cf'},
#  {'product_id': '4cebc26e32dc0a5e',
#   'name': 'Посудомоечная машина узкая BOSCH SPV6HMX4MR',
#   'props': ['Тип сушки интенсивная, класс A',
#    'Инверторный  двигатель\tда',
#    'Индикация на полу\tвремя до завершения мойки',
#    'Третий  уровень загрузки\tесть',
#    'Тип\tузкая',
#    'Таймер отсрочки запуска\tесть',
#    'Ширина\t44.8 см',
#    'Вместимость\t10  комплектов',
#    'Управление со смартфона\tда',
#    'Число   программ класс мойки: A, 5',
#    'Защита   защита от протечек, защита от детей'],
#   'is_reference': False,
#   'reference_id': '5feb5e5d2a37e729'},
#  {'product_id': '4ced407cd09e4a9b',
#   'name': 'Видеокарта ASUS nVidia GeForce RTX 3070 8Gb TUF-RTX3070-O8G-V2-GAMING',
#   'props': ['Тип   подключения\tPCI Express 4.0',
#    'Максимальное   разрешение\t7680x4320',
#    'Объем   видеопамяти\t8192 МБ',
#    'Техпроцесс\t8   нм',
#    'Область  применения\tигровая',
#    'Тип  памяти\tGDDR6',
#    'Разъем   дополнительного питания\t8 pin + 8 pin',
#    'Частота  видеопроцессора\t1500 МГц'],
#   'is_reference': False,
#   'reference_id': '680983361f9768d3'},
#  {'product_id': '4ced45043f6985f7',
#   'name': 'Накопительный водонагреватель термекс (thermex) mechanik mk 30 v, плоская форма',
#   'props': ['Потребляемая мощность\t2000 Вт',
#    'Управление\tмеханическое',
#    'Системы защиты от перегрева, предохранительный клапан',
#    'Индикация включения, нагрева',
#    'Покрытие  бака\tнерж.сталь',
#    "Установка\tвертикальная  на стену с нижней подводкой (½')",
#    'Максимальная   температура воды\t75 °С',
#    'Время  нагрева\t50 мин'],
#   'is_reference': False,
#   'reference_id': '8cf1b9c715f9a13f'},
#  {'product_id': '4cf94a2f50bc2b05',
#   'name': 'Кондиционер cплит-система Jax ACIU-08HE Brisbane Inverter',
#   'props': ['Класс энергоэффективности\tA',
#    'Инверторный\tда',
#    'Уровень   шума внутреннего блока\t25 дБ - 35 дБ',
#    'Особенности   таймер включения/выключения, пульт ДУ, регулировка направления воздушного потока'],
#   'is_reference': False,
#   'reference_id': 'a38aa64a14594b32'},
#  {'product_id': '4d0fd5f33f3620b1',
#   'name': 'Стиральная машина с сушкой Candy CBWD 8514TWH, белый',
#   'props': ['Инверторный двигатель\tда',
#    'Установка\tвстраиваемая',
#    'Загрузка\t8  кг'],
#   'is_reference': False,
#   'reference_id': 'bdcbf9f316fe0125'},
#  {'product_id': '4d2733a8820cc7ad',
#   'name': 'Робот-пылесос Roborock S5 MAX (RU), черный',
#   'props': ['Работа от аккумулятора\tдо 180 мин',
#    'ШхГхВ\t35x35x9.60 см',
#    'Объем  контейнера для воды\t0.29 л',
#    'Тип   уборки\tсухая и влажная',
#    'Тип   контейнера\tдля пыли/воды',
#    'Особенности  конструкции мягкий бампер, встроенные часы, лидар'],
#   'is_reference': False,
#   'reference_id': '3edadb7a2d627f65'},
#  {'product_id': '4d3247b203e2998b',
#   'name': 'Робот-пылесос Xiaomi Roborock S5 MAX (Русская версия) черный',
#   'props': ['Объем контейнера для пыли\t0.46 л',
#    'Тип контейнера\tдля пыли/воды',
#    'Тип   датчиков\tоптические',
#    'Тип  уборки\tсухая и влажная',
#    'Комплектация  боковая щетка, электрощетка'],
#   'is_reference': False,
#   'reference_id': '3edadb7a2d627f65'},
#  ...]

# %%
class Product:
    def __init__(self, product_id: str, name: str, props: [str], is_reference: bool, reference_id: str):
        self.product_id = product_id
        self.name = name
        self.props = props
        self.is_reference = is_reference
        self.reference_id = reference_id

    def __str__(self):
        return f"{'Reference' if self.is_reference else f'Referrer of {self.reference_id}'} {self.name} ({self.product_id}): \n {self.props}"

# %%
all_products = [Product(**p) for p in all_products]

# %%
references = [p for p in all_products if p.is_reference]
references_id_set = set([ref.product_id for ref in references])
products = [p for p in all_products if p.product_id not in references_id_set]

print(*references)
# Out:
# Reference Смартфон Xiaomi Redmi Note 10S NFC 6/128 ГБ RU, белоснежная галька (000740b6c1cc763e):
#  ['Экран\t6.43" (2400x1080) AMOLED 60 Гц', '4 камеры 8 МП, 64 МП, 2 МП, 2 МП', 'Беспроводные интерфейсы инфракрасный порт (IRDA), Bluetooth, Wi-Fi, NFC', 'Встроенная   память\t128 ГБ', 'Оперативная   память\t6 ГБ', 'Аккумулятор\t5000  мА·ч', 'MediaTek   Helio G95', 'SIM-карты\t2  (nano SIM)', 'Операционная  система\tAndroid 11', 'Степень  защиты\tIP53', 'Вес\t179  г', 'Стандарт   связи 2G, 4G LTE, 3G'] Reference Фен LUMME LU-1058 (0083737f904dd9a9):
#  ['Мощность\t1400 Вт', 'Насадки\tконцентратор', 'Вес\t350  г', 'Особенности   складная ручка, защита от перегрева, петля для подвешивания'] Reference 15.6" Ноутбук Lenovo IdeaPad 3 15ARE05 1920x1080, AMD Ryzen 5 4500U 2.3 ГГц, SSD 256 ГБ, AMD Radeon Graphics, DOS, 81W40033RK, Platinum Grey (01378fa92f901df5):
#  ['Экран\t15.6"  (1920x1080) IPS', 'Процессор\tAMD   Ryzen 5 4500U (6x2.30 ГГц)', 'Время   работы от аккумулятора\t14 ч', 'Операционная  система\tDOS', 'Память  RAM 4 ГБ (2666 МГц), SSD 256 ГБ', 'Видеокарта   AMD Radeon Graphics, встроенная'] Reference Микроволновая печь Hyundai HYM-D2071, серебристый (01601abb0bf5133d):
#  ['Объем\t20 л', 'Переключатели\tкнопочные', 'Мощность  микроволн\t700 Вт', 'Внутреннее  покрытие камеры\tэмаль', 'Диаметр   поддона\t245 мм', 'Режимы   работы\tразморозка', 'ШхВхГ\t45.10х28.50х32.60  см', 'Особенности  функция задержки пуска, подсветка камеры, дисплей, блокировка от детей, утапливаемые переключатели', 'Доп.   режимы программирование процесса приготовления, автоматическое приготовление, автоматическая разморозка, звуковой сигнал отключения, ускоренный разогрев'] Reference Принтер лазерный Xerox Phaser 3020BI (01a28e17323d6ef8):
#  ['Интерфейсы USB, Wi-Fi, AirPrint', 'Назначение\tдля   небольшого офиса', 'Печать\tчерно-белая  лазерная', 'Макс.   формат печати\tA4 (210 × 297 мм)'] Reference Газовая плита Weissgauff WGS G4G02 WS, белый (01e52344308143f6):
#  ['Объем духовки\t60 л', 'Управление\tмеханическое', 'Газ-контроль\tдуховки', 'Очистка духовки\tтрадиционная', 'Особенности конструкции\tящик для посуды', 'ШхВхГ\t50х85х60 см', 'Тип   духовки\tгазовая', 'Возможность  подключения к газовому баллону\tесть'] Reference Кофемашина Nivona CafeRomatica NICR 525 (0229abcf2ded1058):
#  ['Давление помпы\t15 бар', 'Количество степеней помола\t3', 'Настройки температура кофе, крепость кофе, жесткость воды', 'Тип  используемого кофе\tмолотый / зерновой', 'Приготовление  капучино\tавтоматическое', 'Одновременная   раздача на 2 чашки\tда', 'Материал   корпуса\tпластик', 'Тип   напитка эспрессо, латте, капучино, американо', 'Доп.   функции подача горячей воды, автоотключение при неиспользовании, автоматическая декальцинация', 'Особенности  конструкции отсек для шнура, дисплей, индикатор включения, индикатор уровня воды, съемный лоток для сбора капель'] Reference Умный браслет Xiaomi Mi Band 7 Global, черный (05a95e7066dc4c52):
#  ['Емкость аккумулятора\t180 мА·ч', 'Экран\t1.62"  (192x490) AMOLED', 'Материал  браслета/ремешка\tтермополиуретан', 'Беспроводная   связь\tBluetooth', 'Совместимость   Android, iOS', 'Мониторинг   постоянное измерение пульса, измерение уровня кислорода в крови'] Reference Компьютерная акустика Defender SPK 33 (05cb692a7fd6c0e6):
#  ['Материал корпуса колонок', 'пластик', 'Компьютерная акустика 2.0', 'Суммарная мощность 5 Вт', 'Диапазон частот 100 - 20000 Гц', 'Однополосные  колонки', 'Питание   от USB'] Reference Умные часы Samsung Galaxy Watch4 40 мм Wi-Fi NFC, черный (05d4f6d7e4fe8c4b):
#  ['Материал браслета/ремешка\tэластомер', 'Защищенность\tвлагозащита', 'Совместимость\tAndroid', 'Экран\t1.2"  (396x396) Super AMOLED', 'Материал  корпуса\tалюминий', 'Емкость  аккумулятора\t247 мА·ч', 'Операционная   система\tWear OS', 'Беспроводная   связь Beidou, Galileo, NFC, вывод аудио на Bluetooth-устройства, ГЛОНАСC, Bluetooth, Wi-Fi, GPS', 'Мониторинг   постоянное измерение пульса, акселерометр, измерение уровня кислорода в крови, ЭКГ, тонометр, мониторинг сна, мониторинг физической активности, мониторинг калорий'] Reference МФУ лазерное Canon i-SENSYS MF3010 (0607c04000d78548):
#  ['Макс. формат печати\tA4 (210 × 297 мм)', 'Интерфейсы\tUSB', 'Функции копирование, сканирование, отправка изображения по e-mail', 'Печать\tчерно-белая   лазерная', 'Назначение   для дома, небольшого офиса'] Reference Микроволновая печь LG MS2535GIS, черный (070dd48327cad4d5):
#  ['Объем\t25 л', 'Инверторное управление мощностью\tда', 'Внутреннее покрытие камеры\tэмаль', 'Переключатели\tсенсорные', 'Мощность  микроволн\t1000 Вт', 'Диаметр  поддона\t292 мм', 'Режимы   работы\tразморозка', 'ШхВхГ\t47.60х27.20х36.80   см', 'Особенности   подсветка камеры, дисплей, блокировка от детей', 'Доп.  режимы автоматический разогрев, программирование процесса приготовления, звуковой сигнал отключения, автоматическое поддержание температуры, автоматическое приготовление, автоматическая разморозка'] Reference Холодильник NORDFROST NRB 152 032, белый (0793124d86c65dc5):
#  ['ШхВхГ 57х188х62 см', 'Общий объем 320 л', 'Объем холодильной камеры 205 л', 'Объем морозильной камеры 115 л', 'Размораживание   морозильной камеры ручное', 'Размораживание  холодильной камеры капельная система', 'Класс  энергопотребления A+', 'Тип   компрессора стандартный', 'Мощность  замораживания 4.5 кг/сутки', 'Особенности   конструкции перевешиваемые двери, антибактериальное покрытие'] Reference Сплит-система Zanussi ZACS-09 HPR/A18/N1, белый (07be2569f73bd6b7):
#  ['Доп. режимы турбо, ночной, осушение, вентиляция', 'Площадь   помещения\t25 м²', 'Мощность  кондиционера\t9 BTU', 'Режим   работы\tохлаждение / обогрев', 'Мощность  охлаждения\t2700 Вт / обогрева: 2800 Вт', 'Класс   энергоэффективности\tA', 'Особенности   пульт ДУ, таймер включения/выключения, регулировка направления воздушного потока, дисплей', 'Уровень  шума внутреннего блока\t24 дБ'] Reference Микроволновая печь LG MB65R95DIS, черный (07d12ec5a962c925):
#  ['Объем\t25 л', 'Инверторное управление мощностью\tда', 'Внутреннее покрытие камеры\tэмаль', 'Диаметр поддона\t292 мм', 'Переключатели\tсенсорные', 'ШхВхГ\t47.60х27.20х38 см', 'Режимы работы гриль, разморозка, микроволны + гриль', 'Особенности система равномерного распределения микроволн, блокировка от детей, подсветка камеры, дисплей', 'Мощность   микроволн\t1000 Вт', 'Доп.  режимы автоматическая разморозка, автоматическое приготовление, звуковой сигнал отключения'] Reference МФУ лазерное Canon i-SENSYS MF443dw (08516de8de755f62):
#  ['Макс. размер отпечатка\t216 × 356 мм', 'Особенности\tавтоматическая двусторонняя печать', 'Назначение\tдля  среднего офиса', 'Печать\tчерно-белая  лазерная', 'Макс.  формат печати\tA4 (210 × 297 мм)', 'Цветной   ЖК-дисплей\tда', 'Функции   сканирование, отправка изображения по e-mail, копирование', 'Интерфейсы  Wi-Fi, USB, Ethernet (RJ-45), AirPrint'] Reference МФУ лазерное HP Color LaserJet Pro MFP M479fdn (08d814610482da4a):
#  ['Назначение\tдля среднего офиса', 'Макс. формат печати\tA4 (210 × 297 мм)', 'Печать\tцветная   лазерная', 'Скорость\t27  стр/мин (цветн. А4)', 'Макс.  размер отпечатка\t216 × 356 мм', 'Особенности\tавтоматическая  двусторонняя печать', 'Цветной  ЖК-дисплей\tда', 'Функции   сканирование, отправка изображения по e-mail, копирование', 'Интерфейсы  AirPrint, Ethernet (RJ-45), USB'] Reference 14" Ноутбук HONOR MagicBook X 14NBR-WAI9 1920x1080, Intel Core i3 10110U 2.1 ГГц, SSD 256 ГБ, Intel UHD Graphics, Windows 10 Home, 5301AAPL, космический серый (09824205ce94d7c9):
#  ['Время работы от аккумулятора\t13.2 ч', 'Видеокарта встроенная, Intel UHD Graphics', 'Экран\t14"   (1920x1080) IPS', 'Процессор\tIntel  Core i3 10110U (2x2.10 ГГц)', 'Операционная  система\tWindows 10 Home', 'Память   SSD 256 ГБ, RAM 8 ГБ (2666 МГц)'] Reference Маршрутизатор TP-LINK ER605 (TL-R605) (0ab98256ef22b592):
#  ['Количество LAN-портов\t1', 'Возможность  установки в стойку\tесть', 'Базовая скорость передачи данных\t1 Гбит/с', 'Особенности\tUSB-порт', 'Количество   WAN-портов\t3', 'Сетевые   стандарты IEEE 802.1q (VLAN), IEEE 802.3u, IEEE 802.3ab, IEEE 802.3x', 'Функции  VPN VPN Endpoint, PPTP, VPN pass through, L2TP, IPSec', '1   гигабитный порт WAN, 3 гигабитных порта WAN/LAN, 1 гигабитный порт LAN; количество одновременных сессий руководство по быстрой настройке, 25000 (TL-R605) и 30000 (ER605); комплектация: адаптер питания, кабель Ethernet RJ45'] Reference Стиральная машина Hansa WHE1206BI, белый (0ac565ce3bfa280b):
#  ['Установка\tвстраиваемая', 'Загрузка\t6  кг', 'ШхГхВ\t59.50х54х82.50  см', 'Скорость  отжима\t1200 об/мин', 'Класс  энергопотребления\tA++', 'Особенности   конструкции\tотсек для жидкого порошка', 'Защита   от детей, от скачков питания, от протечек', 'Доп.функции  выбор температуры стирки, сигнал окончания стирки, контроль баланса, контроль за уровнем пены, выбор скорости отжима, отложенный старт, интеллектуальное управление стиркой'] Reference 50" Телевизор Samsung UE50AU7500U 2021 LED, HDR, черный (0be9800a9a538231):
#  ['Диагональ\t50"', 'Разрешение HD\t4K UHD', 'Частота обновления экрана\t60 Гц', 'Год создания модели\t2021', 'Экосистема умного дома\tУмный дом Яндекса', 'Разрешение\t3840x2160', 'Тип подсветки\tEdge LED', 'Технология экрана HDR, LED', 'Форматы   HDR\tHDR10+', 'Платформа   Smart TV\tTizen', 'Тип  матрицы экрана\tVA', 'Мощность   звука\t20 Вт', 'Беспроводная  связь Wi-Fi, Bluetooth', 'Разъемы  и интерфейсы выход аудио оптический, слот CI, USB Type-A, слот CI/CI+, вход HDMI x 3, Ethernet - RJ-45'] Reference Встраиваемая посудомоечная машина Kuppersberg GSM 6073, серебристый (0c5ac0f8d296c43a):
#  ['Тип\tполноразмерная', '3-й разбрызгиватель\tесть', 'Таймер отсрочки запуска\tесть', 'Число программ класс мойки: A, 7', 'Ширина\t60  см', 'Вместимость\t14   комплектов', 'Третий  уровень загрузки\tесть', 'Индикация  на полу\tлуч', 'Защита\tзащита  от протече', 'Тип сушки класс A, конденсационная'] Reference Смартфон HUAWEI P smart 2021 4/128 ГБ RU, ярко-зеленый (0cb3fc4ae2e1d6fd):
#  ['Оперативная память\t4 ГБ', 'Аккумулятор\t5000 мА·ч', 'SIM-карты\t2 (nano SIM)', 'Вес\t206 г', 'Беспроводные интерфейсы Wi-Fi, NFC, Bluetooth', 'Стандарт связи 3G, 4G LTE', 'Экран\t6.67"   (2400x1080) IPS', 'Встроенная  память\t128 ГБ', 'Hisilicon  Kirin 710A', 'Операционная   система\tAndroid 10', '4   камеры 48 МП, 2 МП, 2 МП, 8 МП'] Reference 23.8" Монитор Lenovo Q24h-10, 2560x1440, 75 Гц, IPS, серый (0db4a3bd5db1f203):
#  ['Особенности\tвстроенные колонки', 'Экран\t2560x1440   (16:9)', 'Тип   матрицы\tIPS', 'Частота  обновления\t75 Гц; отклик: 4 мс', 'Яркость\t300  кд/м²; контрастность: 1000:1', 'Интерфейсы   вход DisplayPort, вход HDMI, USB Type-C'] Reference Видеокарта MSI GeForce GTX 1660 SUPER VENTUS XS OC 6GB, Retail (0e98903bc50f96a4):
#  ['Комплектация\tRetail', 'Частота памяти\t14000 МГц', 'Частота видеопроцессора\t1815 МГц', 'Область  применения\tигровая', 'Объем   видеопамяти\t6144 МБ', 'Тип   памяти\tGDDR6', 'Шина   обмена с памятью\t192 бит', 'Техпроцесс\t12  нм', 'Тип  подключения\tPCI Express 3.0', 'TDP\t125  Вт', 'Разъем  дополнительного питания\t8 pin', 'Максимальное   разрешение\t7680x4320', 'Количество   поддерживаемых мониторов\t4', 'Разъемы   и интерфейсы выход DisplayPort x 3, выход HDMI'] Reference Проточный газовый водонагреватель Bosch WR 10-2P23, белый (0faf2717bf811454):
#  ['Полезная мощность\t17.4 кВт', 'Размеры (ШxВxГ)\t310x580x220 мм', 'Управление\tмеханическое', 'Индикация\tвключения', 'Системы защиты от перегрева, газ-контроль', 'Потребляемая   мощность\t20 Вт', 'Тип  камеры сгорания\tоткрытый', 'Максимальная  температура воды\t60 °С', "Установка\tвертикальная  на стену с нижней подводкой (½')"] Reference 34" Монитор HUAWEI MateView GT Standard Edition, 3440x1440, 165 Гц, *VA, черный (100949e164af5333):
#  ['Частота обновления\t165 Гц; отклик: 4 мс', 'Тип  матрицы\t*VA', 'Яркость\t350  кд/м²; контрастность: 4000:1', 'Игровой  монитор\tда', 'Экран   3440x1440 (21:9), изогнутый', 'Интерфейсы  USB Type-C, вход HDMI x 2, вход DisplayPort', 'Особенности   встроенные колонки, подсветка без мерцания (Flicker-Free), регулировка по высоте'] Reference Видеокарта ASUS TUF Gaming GeForce RTX 3060 Ti V2 OC Edition 8GB (TUF-RTX3060TI-O8G-V2-GAMING), Retail (108edf8f1054d7d4):
#  ['Комплектация\tRetail', 'Техпроцесс\t8 нм', 'Максимальное разрешение\t7680x4320', 'Объем   видеопамяти\t8192 МБ', 'Тип   памяти\tGDDR6', 'Частота  памяти\t14000 МГц', 'Шина   обмена с памятью\t256 бит', 'Частота  видеопроцессора\t1755 МГц', 'Тип   подключения\tPCI Express 4.0', 'TDP\t200  Вт', 'Разъем   дополнительного питания\t8 pin', 'Количество  поддерживаемых мониторов\t4', 'Разъемы  и интерфейсы выход DisplayPort x 3, выход HDMI x 2', 'Поддержка  технологий поддержка трассировки лучей, поддержка Vulkan, поддержка CUDA, поддержка HDCP'] Reference Процессор AMD Ryzen 7 5800X AM4, 8 x 3800 МГц, BOX (1112102ced6b29fe):
#  ['Сокет AM4', 'Дата выхода\tQ4 2020', 'Назначение настольный ПК, игровой', 'Объем   кэша L2/L3\t4 МБ/32 МБ', 'Оперативная  память\t2 x DDR4 3200 МГц', 'Тепловыделение   105 Вт', 'Техпроцесс\t7  нм', 'Количество  потоков\t16', 'Ядро  процессора Vermeer', 'Количество   ядер\t8 x 3800-4700 МГц'] Reference Накопительный электрический водонагреватель Thermex Omnia 80 V, белый (116a0dea1a4ff02d):
#  ['Покрытие бака\tстеклокерамика', 'Управление\tмеханическое', 'Функции\tускоренный нагрев', 'Объем   бака\t80 л', 'Потребляемая  мощность\t2000 Вт', 'Полезная   мощность\t2 кВт', 'Максимальная  температура воды\t75 °С', 'Время  нагрева\t100 мин', 'Размеры  (ШxВxГ)\t542x963x329 мм', 'Системы  защиты\tпредохранительный клапан', 'Индикация   нагрева, включения', "Установка\tвертикальная  на стену с нижней подводкой (½')"] Reference Газовая плита GEFEST 700-02, коричневый (116c9e6140857b4b):
#  ['Настольная\tда', 'Управление\tмеханическое', 'Возможность подключения к газовому баллону\tесть', 'Материал  рабочей поверхности\tэмалированная сталь', 'ШхВхГ\t50х10х37.40  см'] Reference Ноутбук Lenovo IP Gaming 3 15ACH6 (82K201D1RK) (11777853e7c22618):
#  ['Накопитель\t256 ГБ', 'Графика\tNVIDIA GeForce RTX 3050', 'Цвет   товара\tчерный', 'Процессор\tAMD   Ryzen 5 5600H', 'Оперативная   память\t8 ГБ', 'Видеопамять\t4   ГБ'] Reference Смартфон Samsung Galaxy S21 FE (SM-G990E) 8/128 ГБ, белый (117f01fe96fc2b89):
#  ['Оперативная память\t8 ГБ', 'SIM-карты\t2 (nano SIM)', 'Операционная система\tAndroid 12', 'Вес\t177 г', 'Экран\t6.4"   (2340×1080) Dynamic AMOLED 2X 120 Гц', 'Встроенная   память\t128 ГБ', 'Аккумулятор\t4500   мА·ч', 'Samsung   Exynos 2100', 'Степень   защиты\tIP68', '3  камеры 12 МП, 8 МП, 12 МП', 'Беспроводные   интерфейсы Bluetooth, NFC, Wi-Fi', 'Стандарт  связи 5G, 3G, 4G LTE, 2G'] Reference 27" Монитор AOC Q27V4EA, 2560x1440, 75 Гц, IPS, черный (11ec463047d7bc56):
#  ['Экран\t2560x1440 (16:9)', 'Тип матрицы\tIPS', 'Частота обновления\t75 Гц; отклик: 4 мс', 'Интерфейсы вход HDMI, вход DisplayPort', 'Особенности встроенные колонки, подсветка без мерцания (Flicker-Free)', 'Яркость\t250  кд/м²; контрастность: 1000:1', 'Покрытие   экрана\tантибликовое'] Reference 65" Телевизор Xiaomi Mi TV 4S 65 T2S 2020 LED, HDR, серый стальной (1253c3296a3c0153):
#  ['Диагональ\t65"', 'Частота обновления экрана\t60 Гц', 'Экосистема умного дома\tXiaomi Mi Home', 'Разрешение\t3840x2160', 'Разрешение  HD\t4K UHD', 'Форматы   HDR\tHDR10+', 'Год  создания модели\t2020', 'Платформа   Smart TV\tAndroid TV', 'Тип   матрицы экрана\tIPS', 'Мощность   звука\t20 Вт', 'Технология  экрана LED, HDR', 'Беспроводная   связь Bluetooth, Wi-Fi', 'Разъемы   и интерфейсы Ethernet - RJ-45, композитный видеовход, вход HDMI x 3, выход аудио оптический, AV-вход, USB Type-A x 3'] Reference Фен BaByliss 6709DE (125544c9cc07456f):
#  ['Число режимов нагрева\t2', 'Длина сетевого шнура\t2.8 м', 'Насадки концентратор, диффузор', 'Мощность\t2100  Вт', 'Дополнительные  функции ионизация, подача холодного воздуха, независимая регулировка нагрева и воздушного потока', 'Особенности  петля для подвешивания, защита от перегрева'] Reference 23.8" Монитор ASUS VA24ECE, 1920x1080, 75 Гц, IPS, черный (1320d9871e0e41e1):
#  ['Частота обновления\t75 Гц; отклик: 5 мс', 'Особенности поворот на 90 градусов, подсветка без мерцания (Flicker-Free)', 'Покрытие экрана матовое, антибликовое', 'Экран\t1920x1080  (16:9)', 'Тип   матрицы\tIPS', 'Яркость\t250   кд/м²; контрастность: 1000:1', 'Поддержка   FreeSync/G-Sync\tFreeSync', 'Интерфейсы   вход VGA, вход HDMI, USB Type-C'] Reference Холодильник Samsung RB37A5290SA/WT, серебиристый (13238d78e9f5777f):
#  ['Режимы   «отпуск», суперзаморозка', 'ШхВхГ 59.50х201х64.70 см', 'Размораживание No Frost', 'Мощность замораживания 12 кг/сутки', 'Общий  объем 367 л', 'Объем   холодильной камеры 269 л', 'Объем   морозильной камеры 98 л', 'Тип   компрессора инверторный', 'Особенности конструкции перевешиваемые двери, складная полка, дисплей'] Reference 27" Монитор Xiaomi Mi Desktop Monitor RMMNT27NF, 1920x1080, 75 Гц, IPS, EU, черный (13a23947cc15cfe7):
#  ['Экран\t1920x1080  (16:9)', 'Тип  матрицы\tIPS', 'Частота  обновления\t75 Гц; отклик: 6 мс', 'Яркость\t300   кд/м²; контрастность: 1000:1', 'Покрытие  экрана\tматовое', 'Интерфейсы  вход HDMI, вход VGA'] Reference 15.6" Ноутбук Lenovo ThinkBook 15 G3 ACL 1920x1080, AMD Ryzen 5 5500U 2.1 ГГц, SSD 512 ГБ, AMD Radeon Graphics, Windows 10 Pro, 21A4002ERU, mineral grey (13bffaadb1f61ba8):
#  ['Экран\t15.6" (1920x1080) IPS', 'Время работы от аккумулятора\t7.5 ч', 'Процессор\tAMD  Ryzen 5 5500U (6x2.10 ГГц)', 'Операционная   система\tWindows 10 Pro', 'Память  RAM 16 ГБ (3200 МГц), SSD 512 ГБ', 'Видеокарта  встроенная, AMD Radeon Graphics'] Reference 65" Телевизор Xiaomi Mi TV 5 65 Pro 2019 QLED, HDR CN, черный (13f78f44e27fec08):
#  ['Диагональ\t65"', 'Форматы HDR\tHDR10+', 'Разрешение\t3840x2160', 'Тип матрицы экрана\tIPS', 'Мощность звука\t16 Вт', 'Разъемы и интерфейсы AV-вход, вход HDMI x 3, композитный видеовход, Ethernet - RJ-45, USB Type-A x 2, выход аудио коаксиальный', 'Разрешение   HD\t4K UHD', 'Частота  обновления экрана\t60 Гц', 'Год  создания модели\t2019', 'Платформа  Smart TV\tAndroid', 'Экосистема  умного дома\tXiaomi Mi Home', 'Технология   экрана QLED, HDR', 'Беспроводная  связь Wi-Fi, Bluetooth'] Reference Стиральная машина с сушкой Korting KWDI 1485 W, белый (14d7de09535f5f24):
#  ['Установка\tвстраиваемая', 'Скорость отжима\t1400 об/мин', 'Загрузка\t8   кг', 'ШхГхВ\t60х57х82  см', 'Сушка\tпо   времени', 'Класс  энергопотребления\tA', 'Особенности  конструкции\tотсек для жидкого порошка', 'Доп.функции   отложенный старт, контроль баланса, интеллектуальное управление стиркой, выбор скорости отжима, контроль за уровнем пены, выбор температуры стирки', 'Защита   от протечек, от детей'] Reference Микроволновая печь Horizont 20MW800-1479BFS, белый (15045e15063ca106):
#  ['Мощность микроволн\t800 Вт', 'Переключатели кнопочные, поворотные механические', 'Объем\t20   л', 'Внутреннее  покрытие камеры\tэмаль', 'Диаметр   поддона\t255 мм', 'ШхВхГ\t44.40х26х36.20  см', 'Режимы  работы микроволны + гриль, разморозка, гриль', 'Особенности  подсветка камеры, система равномерного распределения микроволн, дисплей, блокировка от детей', 'Доп. режимы программирование процесса приготовления, ускоренная разморозка, ускоренный разогрев, экспресс-режим приготовления, автоматическое поддержание температуры, звуковой сигнал отключения, автоматическое приготовление, автоматическая разморозка, автоматический разогрев'] Reference 16.1" Ноутбук HONOR MagicBook 16 1920x1080, AMD Ryzen 5 5600H 3.3 ГГц, SSD 512 ГБ, HDD отсутствует, AMD Radeon Graphics, Windows 11 Home, 5301ABCM, космический серый (15cb3a27705c8a79):
#  ['Процессор\tAMD Ryzen 5 5600H (6x3.30 ГГц)', 'Операционная система\tWindows 11 Home', 'Видеокарта встроенная, AMD Radeon Graphics', 'Экран\t16.1"  (1920x1080) IPS', 'Память   HDD отсутствует, RAM 16 ГБ (3200 МГц), SSD 512 ГБ'] Reference Смартфон Samsung Galaxy S20 FE (SM-G780G) 6/128 ГБ, синий (160fedb205c7f64e):
#  ['Аккумулятор\t4500 мА·ч', 'Операционная система\tAndroid 10', 'Вес\t190 г', 'Стандарт связи 3G, 4G LTE', 'Экран\t6.5"   (2400x1080) Super AMOLED 120 Гц', 'Встроенная  память\t128 ГБ', 'Оперативная  память\t6 ГБ', 'Qualcomm  Snapdragon 865', 'SIM-карты\t2   (nano SIM)', 'Степень  защиты\tIP68', '3  камеры 12 МП, 8 МП, 12 МП', 'Беспроводные   интерфейсы NFC, Wi-Fi, Bluetooth'] Reference Смартфон Samsung Galaxy A33 5G 6/128 ГБ, черный (161fca3b6bcf5fcc):
#  ['Встроенная память\t128 ГБ', 'SIM-карты\t2 (2 x nano SIM)', '4 камеры 2 МП, 8 МП, 48 МП, 5 МП', 'Экран\t6.4"   (2400x1080) Super AMOLED 90 Гц', 'Оперативная  память\t6 ГБ', 'Аккумулятор\t5000   мА·ч', 'Операционная  система\tAndroid 12', 'Степень  защиты\tIP67', 'Вес\t186   г', 'Беспроводные   интерфейсы Bluetooth, NFC, Wi-Fi', 'Стандарт  связи 4G LTE, 2G, 5G, 3G'] Reference Накопительный электрический водонагреватель Zanussi ZWH/S 15 MINI O, зеленый (168bf704bf291d84):
#  ['Потребляемая мощность\t2500 Вт', "Установка\tвертикальная на стену с нижней подводкой (½')", 'Управление\tмеханическое', 'Индикация\tвключения', 'Объем   бака\t15 л', 'Полезная  мощность\t2.5 кВт', 'Максимальная  температура воды\t75 °С', 'Время  нагрева\t23.4 мин', 'Размеры  (ШxВxГ)\t368x368x340 мм', 'Покрытие  бака\tэмаль', 'Системы защиты от перегрева, предохранительный клапан, обратный клапан'] Reference Умный браслет HUAWEI Band 7 (LEA-B19) графитовый черный (177ccb3b84125efa):
#  ['Модификация\tGPS', 'Материал корпуса\tпластик', 'Материал браслета/ремешка\tсиликон', 'Экран\t1.41" AMOLED', 'Защищенность\tвлагозащита', 'Емкость аккумулятора\t180 мА·ч', 'Совместимость Android, iOS', 'Цвет   товара\tчерный', 'Материал  корпуса\tпластик', 'Материал  браслета/ремешка\tсиликон', 'Беспроводная   связь Bluetooth, GPS', 'Мониторинг  измерение уровня кислорода в крови, мониторинг калорий, мониторинг физической активности, мониторинг сна, акселерометр, постоянное измерение пульса'] Reference Робот-пылесос dreame Dreame D9 RU, белый (1795ccd84570377e):
#  ['Работа от аккумулятора\tдо 150 мин', 'Тип   уборки\tсухая и влажная', 'Тип   контейнера\tдля пыли/воды', 'Объем   контейнера для пыли\t0.57 л', 'Объем   контейнера для воды\t0.27 л', 'Комплектация\tбоковая  щетка', 'Управление   со смартфона\tда', 'Тип   датчиков\tоптические', 'ШхГхВ\t35x35x9.60  см', 'Доп.  функции построение карты помещения, программирование по дням недели, таймер, расчет времени уборки', 'Режимы  работы движение зигзагом, местная уборка, движение по спирали, движение вдоль стен', 'Особенности  конструкции датчик перепада высоты, лидар, мягкий бампер, встроенные часы'] Reference 32" Телевизор Xiaomi Mi TV P1 32 2021 LED RU, черный (187f86e9f768ebeb):
#  ['Диагональ\t32"', 'Разрешение   HD\tHD', 'Частота   обновления экрана\t60 Гц', 'Технология  экрана\tLED', 'Разрешение\t1366x768', 'Тип подсветки\tDirect LED', 'Год  создания модели\t2021', 'Платформа  Smart TV\tAndroid TV', 'Мощность  звука\t10 Вт', 'Беспроводная  связь Wi-Fi, Miracast, Bluetooth', 'Разъемы  и интерфейсы вход HDMI x 3, Ethernet - RJ-45, слот CI/CI+, USB Type-A x 2, выход на наушники, композитный видеовход, AV-вход'] Reference Процессор Intel Core i5-11400F LGA1200, 6 x 2600 МГц, OEM (18a5d547a136f872):
#  ['Оперативная память\t2 x DDR4 3200 МГц', 'Дата выхода\tQ1 2021', 'Сокет   LGA1200', 'Количество  ядер\t6 x 2600-4400 МГц', 'Объем   кэша L2/L3\t3 МБ/12 МБ', 'Тепловыделение  65 Вт', 'Техпроцесс\t14   нм', 'Количество  потоков\t12', 'Ядро  процессора Rocket Lake-S', 'Назначение   настольный ПК, игровой'] Reference Смартфон Samsung Galaxy A23 4/64 ГБ, черный (18f70798698916ae):
#  ['Беспроводные интерфейсы Wi-Fi, Bluetooth, NFC', 'Стандарт связи 2G, 3G, 4G LTE', 'Экран\t6.6"  (2408x1080) PLS 90 Гц', 'Встроенная   память\t64 ГБ', 'Оперативная   память\t4 ГБ', 'Аккумулятор\t5000   мА·ч', 'Qualcomm  Snapdragon 680', 'SIM-карты\t2   (2 x nano SIM)', 'Операционная   система\tAndroid 12', 'Вес\t195  г', '4  камеры 2 МП, 50 МП, 5 МП, 2 МП'] Reference Встраиваемая посудомоечная машина Beko DIS25010, белый (193e2a2bb43ac363):
#  ['Тип\tузкая', 'Ширина\t44.8 см', 'Вместимость\t10 комплектов', 'Третий уровень загрузки\tесть', 'Индикация на полу\tлуч', 'Таймер отсрочки запуска\tесть', 'Тип защиты от протечек\tчастичная (корпус)', 'Защита\tзащита   от протечек', 'Число  программ 5, класс мойки: A', 'Тип   сушки класс A, конденсационная'] Reference Wi-Fi роутер D-link DSL-2640U/R1A (19a0e085f1c80eb6):
#  ['Подключение к интернету (WAN)\tADSL', 'Частотный   диапазон устройств Wi-Fi\t2.4 ГГц', 'Функции  и особенности\tподдержка IPv6', 'Скорость   портов\t100 Мбит/с', 'Макс.   скорость беспроводного соединения 150 Мбит/с', 'Количество  LAN-портов 4', 'Стандарт Wi-Fi 802.11 g (Wi-Fi 3), n (Wi-Fi 4), b (Wi-Fi 1)'] Reference Накопительный электрический водонагреватель Ariston BLU EVO R 30 RU, 2019 г, белый/синий (1a3d1cb265de4c4e):
#  ['Максимальная температура воды\t75 °С', 'Размеры (ШxВxГ)\t447x447x389 мм', 'Управление\tмеханическое', 'Индикация\tвключения', 'Объем  бака\t30 л', 'Потребляемая  мощность\t1500 Вт', 'Полезная   мощность\t1.5 кВт', 'Время   нагрева\t70 мин', 'Покрытие   бака\tэмаль', "Установка\tвертикальная  на стену с нижней подводкой (½')", 'Системы   защиты предохранительный клапан, от перегрева'] Reference Робот-пылесос Xiaomi Viomi Cleaning Robot V3, черный (1c370548bdb8590d):
#  ['Объем контейнера для пыли\t0.55 л', 'Тип датчиков\tоптические', 'Комплектация электрощетка, боковая щетка', 'Режимы работы движение зигзагом, местная уборка', 'Тип  уборки\tсухая и влажная', 'Тип   контейнера\tдля пыли/воды', 'Объем   контейнера для воды\t0.55 л', 'Работа   от аккумулятора\tдо 170 мин', 'Управление  со смартфона\tда', 'ШхГхВ\t35x35x9.50   см', 'Доп.  функции построение карты помещения, программирование по дням недели, таймер, расчет времени уборки', 'Особенности   конструкции встроенные часы, мягкий бампер'] Reference Электрическая плита Zigmund & Shtain ZIP-551, черный (1c8762ee8c6d4a9b):
#  ['Настольная\tда', 'Управление\tэлектронное', 'Макс. потребляемая мощность\t2000 Вт', 'Доп. функции\tтаймер', 'Особенности конструкции\tдисплей', 'ШхВхГ\t28х6х36 см', 'Материал   рабочей поверхности\tстеклокерамика', 'Защитное   отключение конфорок, блокировка панели управления'] Reference Процессор Intel Core i9-12900KF LGA1700, 16 x 3200 МГц, OEM (1d56acfbc4983b65):
#  ['Сокет  LGA1700', 'Количество потоков\t24', 'Назначение игровой, настольный ПК', 'Количество  ядер\t16 x 3200-5200 МГц', 'Объем  кэша L2/L3\t14 МБ/30 МБ', 'Тепловыделение  241 Вт', 'Техпроцесс\t10  нм', 'Alder  Lake-S', 'Дата   выхода\tQ4 2021', 'Оперативная  память DDR5 3200/4800 МГц, 2 x DDR4'] Reference Умные часы Samsung Galaxy Watch3 41 мм Wi-Fi NFC RU, бронза/розовый (1d710b10c62c6a00):
#  ['Материал браслета/ремешка\tкожа', 'Защищенность\tвлагозащита', 'Емкость аккумулятора\t247 мА·ч', 'Совместимость iOS, Android', 'Экран\t1.18"  (360x360) Super AMOLED', 'Материал  корпуса\tнерж. сталь', 'Операционная  система\tTizen', 'Беспроводная   связь Wi-Fi, Beidou, GPS, NFC, Bluetooth, ГЛОНАСC, вывод аудио на Bluetooth-устройства, Galileo', 'Мониторинг   акселерометр, мониторинг сна, постоянное измерение пульса, измерение уровня кислорода в крови, мониторинг физической активности, тонометр, мониторинг калорий, ЭКГ'] Reference Wi-Fi роутер D-link DIR-620S (1eca353c3aaa0108):
#  ['Поддержка USB-модема', 'Количество LAN-портов 4', 'Функции и особенности режим репитера (повторителя), поддержка IPv6, режим моста, UPnP AV-сервер', 'Частотный  диапазон устройств Wi-Fi\t2.4 ГГц', 'Скорость   портов\t100 Мбит/с', 'Макс.  скорость беспроводного соединения 300 Мбит/с', 'Стандарт  Wi-Fi 802.11 n (Wi-Fi 4), a (Wi-Fi 2), b (Wi-Fi 1), g (Wi-Fi 3)', 'Подключение  к интернету (WAN) внешний модем, Ethernet RJ-45'] Reference Кофемашина Saeco Lirika One Touch Cappuccino (1f21918ceb5d345c):
#  ['Давление помпы\t15 бар', 'Приготовление капучино\tавтоматическое', 'Количество степеней помола\t5', 'Одновременная раздача на 2 чашки\tда', 'Настройки крепость кофе, объем порции горячей воды', 'Тип  используемого кофе\tзерновой', 'Материал   корпуса\tпластик', 'Тип   напитка эспрессо, ристретто, латте макиато, американо, капучино', 'Доп.  функции подача горячей воды, автоотключение при неиспользовании, автоматическая декальцинация', 'Особенности  конструкции индикатор уровня воды, подсветка дисплея, съемный лоток для сбора капель, раздельные бойлеры, индикатор включения, дисплей, контейнер для отходов'] Reference Электрическая плита Weissgauff WES E2V12 WS, белый (1f3709ce593ece4a):
#  ['Управление\tмеханическое', 'Очистка духовки\tтрадиционная', 'Тип  духовки\tэлектрическая', 'Объем   духовки\t60 л', 'Доп.  функции\tтермостат', 'ШхВхГ\t50х87х60  см', 'Особенности   конструкции ящик для посуды, эмаль легкой чистки'] Reference Накопительный электрический водонагреватель Edisson ER 50V (20ba2dcb69e1e35a):
#  ['Объем бака\t50 л', 'Время нагрева\t105 мин', 'Покрытие бака\tэмаль', "Установка\tвертикальная на стену с нижней подводкой (½')", 'Управление\tмеханическое', 'Индикация\tвключения', 'Потребляемая   мощность\t1500 Вт', 'Полезная  мощность\t1.5 кВт', 'Максимальная   температура воды\t75 °С', 'Размеры   (ШxВxГ)\t445x530x460 мм', 'Системы   защиты от перегрева, предохранительный клапан, обратный клапан'] Reference 50" Телевизор Philips 50PUS7406/60 2021 HDR, черный (20cc3e4f7665c876):
#  ['Диагональ\t50"', 'Год создания модели\t2021', 'Разрешение\t3840x2160', 'Тип подсветки\tDirect LED', 'Беспроводная связь Wi-Fi, Bluetooth', 'Разрешение   HD\t4K UHD', 'Частота   обновления экрана\t60 Гц', 'Технология   экрана\tHDR', 'Платформа   Smart TV\tAndroid TV', 'Тип  матрицы экрана\tIPS', 'Мощность  звука\t20 Вт', 'Форматы   HDR Dolby Vision, HDR10+', 'Разъемы   и интерфейсы слот CI/CI+, USB Type-A x 2, Ethernet - RJ-45, вход HDMI x 4, слот CI, выход на наушники, выход аудио оптический'] Reference Wi-Fi роутер Mercusys MW301R (21991eb9be11bcfe):
#  ['Подключение к интернету (WAN)\tEthernet RJ-45', 'Частотный  диапазон устройств Wi-Fi\t2.4 ГГц', 'Скорость  портов\t100 Мбит/с', 'Макс.   скорость беспроводного соединения 300 Мбит/с', 'Количество   LAN-портов 2', 'Стандарт   Wi-Fi 802.11 n (Wi-Fi 4), b (Wi-Fi 1), g (Wi-Fi 3), a (Wi-Fi 2)', 'Функции   и особенности режим моста, WDS'] Reference 50" Телевизор Samsung UE50AU7002U 2022, черный (2215bb3c753bac5a):
#  ['Диагональ\t50"', 'Частота обновления экрана\t60 Гц', 'Год создания модели\t2022', 'Разрешение\t3840x2160', 'Тип подсветки\tEdge LED', 'Мощность звука\t20 Вт', 'Разрешение  HD\t4K UHD', 'Форматы  HDR\tHDR10+', 'Платформа   Smart TV\tTizen', 'Экосистема   умного дома\tУмный дом Яндекса', 'Разъемы   и интерфейсы слот CI/CI+, вход HDMI x 2, Ethernet - RJ-45', 'Беспроводная   связь Wi-Fi, Bluetooth'] Reference Планшет Xiaomi Pad 5 Global, 6 ГБ/128 ГБ, Wi-Fi, космический серый (250b2183453afede):
#  ['Экран 120 Гц, 11" (2560x1600), 2K QHD IPS ', 'Процессор\tSnapdragon  860', 'Операционная   система\tAndroid 11', 'Камеры  основная 13 МП, фронтальная 8 МП', 'Емкость аккумулятора\t8720 мА·ч', 'Размеры  вес: 511 г, 254.69x166.25x6.85 мм'] Reference Стиральная машина с сушкой GRAUDE EWTA 80.0, белый (257d8f18f913e5d7):
#  ['Установка\tвстраиваемая', 'Защита от детей, от протечек', 'Загрузка\t8   кг', 'ШхГхВ\t60х54х82   см', 'Скорость  отжима\t1400 об/мин', 'Сушка\tпо   времени', 'Класс   энергопотребления\tA', 'Доп.функции контроль за уровнем пены, выбор скорости отжима, контроль баланса, интеллектуальное управление стиркой, отложенный старт, выбор температуры стирки, сигнал окончания стирки'] Reference Смартфон Samsung Galaxy M52 5G 8/128 ГБ, черный (25d66337f5007356):
#  ['Экран\t6.7" (2400x1080) Super AMOLED Plus 120 Гц', 'Аккумулятор\t5000 мА·ч', 'Встроенная   память\t128 ГБ', 'Оперативная   память\t8 ГБ', '3  камеры 12 МП, 5 МП, 64 МП', 'Операционная система\tAndroid 11', 'Вес\t173 г', 'Qualcomm   Snapdragon 778G', 'SIM-карты\t2   (nano SIM)', 'Стандарт  связи 5G, 4G LTE, 3G', 'Беспроводные интерфейсы Bluetooth, NFC, Wi-Fi'] Reference Робот-пылесос Xiaomi Mi Robot Vacuum Cleaner 1S CN, белый (26cd2d13903ad9b9):
#  ['ШхГхВ\t35x35x9.60 см', 'Режимы работы движение зигзагом, быстрая уборка, местная уборка, движение вдоль стен', 'Особенности конструкции встроенные часы, мягкий бампер', 'Тип   уборки\tсухая', 'Тип  контейнера\tдля пыли', 'Объем   контейнера для пыли\t0.42 л', 'Работа  от аккумулятора\tдо 150 мин', 'Управление   со смартфона\tда', 'Тип  датчиков\tоптические', 'Комплектация   боковая щетка, электрощетка', 'Доп.  функции сигнал при застревании, построение карты помещения, расчет времени уборки, программирование по дням недели, таймер, сигнал при разрядке аккумулятора'] Reference Компьютерная акустика Perfeo PHAROS (2714c15923a2aeeb):
#  ['Компьютерная акустика 2.0', 'Однополосные колонки', 'Питание от USB', 'Суммарная  мощность 5 Вт', 'Диапазон  частот 50 - 18000 Гц'] Reference Холодильник Бирюса 118, белый (28085e941cde1639):
#  ['ШхВхГ   48х145х60.50 см', 'Объем холодильной камеры    125 л', 'Мощность замораживания  4 кг/сутки', 'Общий  объем 180 л', 'Размораживание  морозильной камеры   ручное', 'Размораживание   холодильной камеры   капельная система', 'Класс  энергопотребления A', 'Объем  морозильной камеры    55 л', 'Тип   компрессора стандартный', 'Особенности  конструкции перевешиваемые двери'] Reference Сплит-система Jax ACN-07-HE, белый (28b35afffe8435b8):
#  ['Фильтры\tдезодорирующий', 'Режим   работы\tохлаждение / обогрев', 'Мощность  охлаждения\t2100 Вт / обогрева: 2100 Вт', 'Уровень  шума внутреннего блока\t22 дБ - 34 дБ', 'Особенности регулировка направления воздушного потока, дисплей, пульт ДУ, таймер включения/выключения', 'Доп.   режимы осушение, вентиляция, ночной'] Reference Кофемашина Melitta Caffeo Solo (2948d875bd6e4a2d):
#  ['Тип используемого кофе\tзерновой', 'Одновременная раздача на 2 чашки\tда', 'Материал корпуса\tпластик', 'Особенности конструкции дисплей, отсек для шнура, индикатор включения, съемный лоток для сбора капель, индикатор уровня воды, контейнер для отходов, подсветка дисплея', 'Давление  помпы\t15 бар', 'Количество  степеней помола\t3', 'Тип   напитка эспрессо, американо', 'Настройки   крепость кофе, температура кофе, объем порции горячей воды, жесткость воды', 'Доп.   функции автоматическая декальцинация, автоотключение при неиспользовании, подогрев чашек'] Reference Микроволновая печь LG MB65W65DIR, серебристый (29fe74264baec52c):
#  ['Мощность микроволн\t1150 Вт', 'Диаметр поддона\t292 мм', 'Переключатели\tсенсорные', 'ШхВхГ\t47.60х27.20х38.90 см', 'Объем\t25  л', 'Инверторное   управление мощностью\tда', 'Режимы   работы микроволны + гриль, разморозка, гриль', 'Доп.   режимы автоматический разогрев, автоматическая разморозка, автоматическое приготовление, звуковой сигнал отключения', 'Особенности   подсветка камеры, блокировка от детей, дисплей, система равномерного распределения микроволн, утапливаемые переключатели'] Reference Накопительный электрический водонагреватель Thermex TitaniumHeat 80 V, белый (2a4be1cc65af864a):
#  ['Объем бака\t80 л', 'Потребляемая мощность\t1500 Вт', 'Время нагрева\t170 мин', 'Управление\tмеханическое', 'Полезная  мощность\t1.5 кВт', 'Максимальная   температура воды\t75 °С', 'Размеры  (ШxВxГ)\t445x751x459 мм', 'Покрытие   бака\tстеклокерамика', "Установка\tвертикальная  на стену с нижней подводкой (½')", 'Системы  защиты обратный клапан, от перегрева, предохранительный клапан', 'Индикация  включения, нагрева'] Reference Wi-Fi роутер TP-LINK TL-WR842N (2b0ab54004b858af):
#  ['Скорость портов\t100 Мбит/с', 'Количество LAN-портов 4', 'Функции и особенности поддержка IPv6, режим моста, WDS, UPnP AV-сервер', 'Частотный  диапазон устройств Wi-Fi\t2.4 ГГц', 'Макс.  скорость беспроводного соединения 300 Мбит/с', 'Поддержка  USB-модема', 'Подключение   к интернету (WAN) внешний модем, Ethernet RJ-45', 'Стандарт  Wi-Fi 802.11 b (Wi-Fi 1), g (Wi-Fi 3), n (Wi-Fi 4), a (Wi-Fi 2)'] Reference Смартфон HUAWEI Nova Y70 4/128 ГБ, crystal blue (2bc1c5675d111d9f):
#  ['Экран\t6.75" (1600x720) TFT', 'Встроенная память\t128 ГБ', 'Аккумулятор\t6000 мА·ч', 'SIM-карты\t2', '3 камеры 5 МП, 48 МП, 2 МП', 'Оперативная   память\t4 ГБ', 'Вес\t199 г', 'Стандарт  связи 2G, 3G, 4G LTE', 'Беспроводные   интерфейсы Wi-Fi, Bluetooth'] Reference Микроволновая печь PANASONIC NN-C69MSZPE серебристый/черный (2bcb6cbc8732a9b6):
#  ['Переключатели\tкнопочные', 'ШхВхГ\t52х32х52 см', 'Цвет  товара\tчeрный', 'Объем\t30  л', 'Мощность   микроволн\t1000 Вт', 'Внутреннее  покрытие камеры\tнерж. сталь', 'Режимы работы гриль, разморозка'] Reference Умные часы Amazfit Bip U RU, розовый (2c278b066237ccc0):
#  ['Материал корпуса\tпластик', 'Материал браслета/ремешка\tсиликон', 'Защищенность\tвлагозащита', 'Операционная система\tZepp OS', 'Мониторинг постоянное измерение пульса, акселерометр, мониторинг калорий, мониторинг физической активности, измерение уровня кислорода в крови, мониторинг сна', 'Экран\t1.43"  (320x302) IPS', 'Беспроводная   связь\tBluetooth', 'Емкость   аккумулятора\t230 мА·ч', 'Совместимость  iOS, Android'] Reference 15.6" Ноутбук Lenovo V15 ADA 1920x1080, AMD Ryzen 5 3500U 2.1 ГГц, SSD 256 ГБ, AMD Radeon Vega 8, без ОС, 82C7000YRU, Iron Grey (2ce6f8d283aa69c5):
#  ['Экран\t15.6" (1920x1080) TN', 'Процессор\tAMD Ryzen 5 3500U (4x2.10 ГГц)', 'Операционная система\tбез ОС', 'Время   работы от аккумулятора\t6 ч', 'Память  RAM 8 ГБ (2400 МГц), SSD 256 ГБ', 'Видеокарта   встроенная, AMD Radeon Vega 8'] Reference Электрическая плита Weissgauff WES E2V02 WS, белый (2d779b8a8ff7d278):
#  ['Тип духовки\tэлектрическая', 'Объем духовки\t60 л', 'Управление\tмеханическое', 'Очистка духовки\tтрадиционная', 'Доп. функции\tтермостат', 'ШхВхГ\t50х85х60 см', 'Особенности   конструкции ящик для посуды, подсветка духовки', 'Материал   рабочей поверхности\tстеклокерамика'] Reference Сплит-система NewTek NT-65D07, белый (2d9276456599a944):
#  ['Площадь помещения\t20 м²', 'Мощность охлаждения\t2160 Вт / обогрева: 2200 Вт', 'Класс энергоэффективности\tA', 'Особенности регулировка направления воздушного потока, таймер включения/выключения, дисплей, пульт ДУ', 'Мощность  кондиционера\t7 BTU', 'Режим   работы\tохлаждение / обогрев', 'Уровень  шума внутреннего блока\t24 дБ', 'Доп.  режимы турбо, осушение, вентиляция, ночной'] Reference Беспроводные наушники Samsung Galaxy Buds Pro, белый (2e5af7eb35741f68):
#  ['Конструкция\tвнутриканальные', 'Подключение\tBluetooth 5.0', 'Степень защиты\tIPX7', 'Количество микрофонов\t6', 'Время работы с выключенным ANC\t5 ч', 'Время работы с включенным ANC\t5 ч', 'Активное   шумоподавление (ANC)\tесть', 'Тип  зарядки кейса\tбеспроводная зарядка', 'Время   работы от аккумулятора в кейсе\t28 ч'] Reference Смартфон Xiaomi Poco M4 Pro 4G 6/128 ГБ RU, заряженный черный (2e9d9df33a9c55f0):
#  ['Оперативная память\t6 ГБ', 'MediaTek Helio G96', 'Стандарт связи 4G LTE, 3G, 2G', 'Экран\t6.43"   (2400x1080) AMOLED 90 Гц', 'Встроенная  память\t128 ГБ', 'Аккумулятор\t5000  мА·ч', 'SIM-карты\t2   (2 x nano SIM)', 'Операционная   система\tAndroid 11', 'Степень  защиты\tIP53', 'Вес\t179.5  г', '3   камеры 2 МП, 64 МП, 8 МП', 'Беспроводные   интерфейсы Bluetooth, Wi-Fi, инфракрасный порт (IRDA), NFC'] Reference Стиральная машина TEKA LI5 1080 (EXP), белый (2ea467129e23718e):
#  ['Установка\tвстраиваемая', 'Класс энергопотребления\tA+++', 'Загрузка\t8  кг', 'ШхГхВ\t60х57х82  см', 'Скорость  отжима\t1000 об/мин', 'Защита   от протечек, от детей', 'Доп.функции   выбор скорости отжима, контроль баланса, отложенный старт, выбор температуры стирки, интеллектуальное управление стиркой, сигнал окончания стирки, контроль за уровнем пены'] Reference Индукционная плита Kitfort КТ-144 (2eb451c97426f306):
#  ['Цвет\tчерный', 'Настольная\tда', 'Управление\tэлектронное', 'Макс. потребляемая мощность\t1800 Вт', 'Материал  рабочей поверхности\tстеклокерамика', 'Доп.  функции\tтаймер', 'ШхВхГ\t41.40х4.90х31.30   см'] Reference Планшет Samsung Galaxy Tab A8, 3 ГБ/32 ГБ, Wi-Fi + Cellular, темно-серый (2f92010236ee9319):
#  ['Операционная система\tAndroid 11', 'Емкость аккумулятора\t7040 мА·ч', 'Особенности cлот для карты памяти, датчик освещенности, гироскоп, акселерометр, встроенный микрофон, датчик Холла, компас', 'Процессор\tUnisoc   Tiger T618', 'Экран   TFT , 10.5" (1920x1200), 60 Гц', 'Камеры   основная 8 МП, фронтальная 5 МП', 'Размеры   вес: 508 г, 246.8x161.9x6.9 мм'] Reference Сплит-система Electrolux EACS-09HF/N3_22Y, белый (2fb0f64b2f454ce5):
#  ['Доп. режимы ночной, вентиляция, осушение', 'Линейка\tFusion  Ultra', 'Площадь   помещения\t25 м²', 'Режим   работы\tохлаждение / обогрев', 'Мощность   охлаждения\t2600 Вт / обогрева: 2700 Вт', 'Класс  энергоэффективности\tA', 'Особенности   пульт ДУ, дисплей, таймер включения/выключения'] Reference Беспроводные наушники Apple AirPods 2 с зарядным футляром MV7N2, белый (3024dbf152225504):
#  ['Количество драйверов\t1', 'Импеданс\t32 Ом', 'Конструкция\tвкладыши  (открытые)', 'Подключение\tBluetooth   5.0', 'Тип  зарядки кейса\tLightning', 'Количество  микрофонов\t2', 'Тип   излучателей\tдинамические', 'Время  работы\t5 ч', 'Время  работы от аккумулятора в кейсе\t24 ч', 'Диапазон   воспроизводимых частот\t20-20000 Гц'] Reference Микроволновая печь NATIONAL NK-MW262S20, черный (31312fb0f5ebc4a2):
#  ['Объем\t20 л', 'Мощность микроволн\t700 Вт', 'Переключатели\tсенсорные', 'Режимы работы\tразморозка', 'Диаметр   поддона\t255 мм', 'ШхВхГ\t44х25.90х32.30   см', 'Особенности   дисплей, блокировка от детей, программирование рецептов в память, подсветка камеры', 'Доп.   режимы программирование процесса приготовления, автоматическая разморозка, звуковой сигнал отключения, автоматическое приготовление, экспресс-режим приготовления'] Reference Видеокарта MSI GeForce GTX 1050 Ti 4GT OC, Retail (31862a08efb59198):
#  ['Комплектация\tRetail', 'Область   применения\tигровая', 'Объем  видеопамяти\t4096 МБ', 'Тип  памяти\tGDDR5', 'Частота   памяти\t7008 МГц', 'Техпроцесс\t14 нм', 'Шина   обмена с памятью\t128 бит', 'Частота  видеопроцессора\t1455 МГц', 'Тип  подключения\tPCI Express 3.0', 'TDP\t75  Вт', 'Максимальное   разрешение\t7680x4320', 'Количество  поддерживаемых мониторов\t3', 'Разъемы  и интерфейсы выход HDMI, выход DVI, выход DisplayPort'] Reference Фен MOSER 4350-0050 (32a7b966f7ab8c72):
#  ['Мощность\t2200   Вт', 'Насадки\tконцентратор', 'Длина сетевого шнура\t2.8 м', 'Особенности съемный фильтр, петля для подвешивания', 'Число  режимов нагрева\t3', 'Вес\t510   г', 'Покрытие  керамическое, турмалиновое', 'Дополнительные  функции независимая регулировка нагрева и воздушного потока, подача холодного воздуха, ионизация'] Reference Встраиваемая посудомоечная машина Midea MID45S130i, серебристый (32f6854f801cbf10):
#  ['Тип\tузкая', 'Индикация на полу\tнет', 'Управление со смартфона\tда', 'Ширина\t44.8   см', 'Вместимость\t10  комплектов', 'Таймер   отсрочки запуска\tесть', 'Защита\tзащита  от протечек', 'Тип   защиты от протечек\tполная', 'Число  программ 5, класс мойки: A'] Reference Холодильник NORDFROST NR 403 AW, белый (3312f087da822eaa):
#  ['Общий объем 111 л', 'Размораживание ручное', 'Объем холодильной камеры 100 л', 'ШхВхГ  50х86х53 см', 'Класс   энергопотребления A+', 'Объем  морозильной камеры 11 л', 'Тип   компрессора стандартный', 'Особенности   конструкции перевешиваемые двери, антибактериальное покрытие'] Reference Процессор Intel Core i3-10105F LGA1200, 4 x 3700 МГц, BOX (343e6f18eed4247e):
#  ['LGA1200', 'Оперативная память\t2 x DDR4 2666 МГц', 'Тепловыделение', 'Техпроцесс\t14 нм', 'Comet Lake-S', 'Дата выхода\tQ1 2021', 'Назначение игровой, настольный ПК', 'Количество   ядер\t4 x 3700-4400 МГц', 'Объем  кэша L2/L3\t1 МБ/6 МБ', 'Количество   потоков\t8'] Reference Процессор Intel Core i5-12400F LGA1700, 6 x 2500 МГц, OEM (3478f4ee87d43aee):
#  ['Техпроцесс\t10 нм', 'Оперативная память 2 x DDR4, DDR5 3200/4800 МГц', 'Сокет  LGA1700', 'Количество  ядер\t6 x 2500-4400 МГц', 'Объем   кэша L2/L3\t7.50 МБ/18 МБ', 'Тепловыделение   65 Вт', 'Количество  потоков\t12', 'Ядро   процессора Alder Lake-S', 'Назначение\tнастольный   ПК', 'Дата  выхода\tQ1 2022'] Reference Робот-пылесос Xiaomi Mi Robot Vacuum-Mop 2 Ultra EU, черный (349fdfb870581e8c):
#  ['Тип контейнера\tдля пыли/воды', 'Комплектация\tбоковая щетка', 'Работа от аккумулятора\tдо 90 мин', 'Управление со смартфона\tда', 'Тип  уборки\tсухая и влажная', 'Объем  контейнера для пыли\t0.55 л', 'Объем   контейнера для воды\t0.2 л', 'Тип   датчиков\tоптические', 'Доп.   функции построение карты помещения, программирование по дням недели', 'Режимы   работы местная уборка, движение вдоль стен', 'ШхГхВ\t35.30x35.30x9.88   см', 'Особенности   конструкции лидар, индикатор заполнения пылесборника, мягкий бампер'] Reference Накопительный электрический водонагреватель Thermex TitaniumHeat 150 V, белый (3506a28b65ac9e2b):
#  ['Объем бака\t150 л', 'Потребляемая мощность\t1500 Вт', 'Управление\tмеханическое', 'Полезная   мощность\t1.5 кВт', 'Максимальная  температура воды\t75 °С', 'Время   нагрева\t280 мин', 'Размеры  (ШxВxГ)\t445x1283x459 мм', 'Покрытие   бака\tстеклокерамика', "Установка\tвертикальная   на стену с нижней подводкой (½')", 'Системы   защиты предохранительный клапан, обратный клапан', 'Индикация  нагрева, включения'] Reference Накопительный электрический водонагреватель Electrolux EWH 30 Quantum Pro, белый (3548c7f528527e95):
#  ['Объем бака\t30 л', 'Максимальная температура воды\t75 °С', "Установка\tвертикальная на стену с нижней подводкой (½')", 'Управление\tмеханическое', 'Потребляемая  мощность\t1500 Вт', 'Полезная   мощность\t1.5 кВт', 'Время   нагрева\t95 мин', 'Размеры  (ШxВxГ)\t340x570x340 мм', 'Покрытие   бака\tэмаль', 'Индикация   нагрева, включения', 'Системы  защиты от включения без воды, от перегрева, обратный клапан, предохранительный клапан'] Reference Проточный электрический водонагреватель Thermex Surf 5000, душ, белый (35b3667e9c4d5ab3):
#  ['Управление\tмеханическое', 'Потребляемая мощность\t5000 Вт', 'Полезная   мощность\t5 кВт', 'Размеры   (ШxВxГ)\t135x194x80 мм', 'Индикация\tвключения', 'Системы   защиты от перегрева, от включения без воды', "Установка\tвертикальная  на стену (½')"] Reference Микроволновая печь Samsung GE88SUW/BW, белый (35dcbf60d7bbfcee):
#  ['Объем\t23 л', 'Внутреннее покрытие камеры\tбиокерамическая эмаль', 'Переключатели\tкнопочные', 'Доп. режимы режим удаления запахов, автоматическое приготовление', 'Мощность   микроволн\t800 Вт', 'Диаметр   поддона\t288 мм', 'ШхВхГ\t48.90х27.50х36   см', 'Режимы   работы микроволны + гриль, разморозка, гриль', 'Особенности  кнопка +30 секунд, блокировка от детей, дисплей, подсветка камеры'] Reference Накопительный электрический водонагреватель Midea MWH-5015-CVM, белый (364c0875ba59dbbb):
#  ['Полезная мощность\t1.5 кВт', "Установка\tвертикальная на стену с нижней подводкой (½')", 'Управление\tмеханическое', 'Индикация\tнагрева', 'Объем   бака\t50 л', 'Потребляемая   мощность\t1500 Вт', 'Максимальная   температура воды\t75 °С', 'Время   нагрева\t70.2 мин', 'Размеры  (ШxВxГ)\t385x697x385 мм', 'Покрытие   бака\tэмаль', 'Системы  защиты\tпредохранительный клапан'] Reference Wi-Fi роутер Mercusys AC10 (3739ab3aad1cc751):
#  ['Подключение к интернету (WAN)\tEthernet RJ-45', 'Функции и особенности\tподдержка IPv6', 'Частотный   диапазон устройств Wi-Fi\t2.4 / 5 ГГц (одновременная работа)', 'Скорость  портов\t100 Мбит/с', 'Макс.   скорость беспроводного соединения 1167 Мбит/с', 'Количество   LAN-портов 2', 'Стандарт   Wi-Fi 802.11 n (Wi-Fi 4), b (Wi-Fi 1), a (Wi-Fi 2), ac (Wi-Fi 5), g (Wi-Fi 3)'] Reference Беспроводные наушники Apple AirPods Pro MagSafe, белый (3770f7338ab697da):
#  ['Активное шумоподавление (ANC)\tесть', 'Конструкция\tвнутриканальные (закрытые)', 'Подключение\tBluetooth 5.0', 'Количество микрофонов\t2', 'Степень   защиты\tIPX4', 'Тип   излучателей\tдинамические', 'Время  работы\t4.5 ч', 'Вес\t10.8  г', 'Время   работы от аккумулятора в кейсе\t24 ч', 'Тип  зарядки кейса Lightning, беспроводная зарядка'] Reference Принтер лазерный HP Laser 107w (377312a4a7d64f81):
# ...
#  ["Установка\tвертикальная на стену с нижней подводкой (½')", 'Управление\tмеханическое', 'Цвет  товара\tбелый', 'Объем   бака\t50 л', 'Потребляемая   мощность\t1500 Вт', 'Полезная   мощность\t1.5 кВт', 'Максимальная   температура воды\t75 °С', 'Время   нагрева\t90 мин', 'Размеры  (ШxВxГ)\t378x722x365 мм', 'Покрытие  бака\tэмаль', 'Системы  защиты обратный клапан, предохранительный клапан', 'Индикация  нагрева, включения'] Reference Фен Philips BHD341 (f0fc718b6d6c7d8e):
#  ['Мощность\t2100 Вт', 'Дополнительные функции\tподача холодного воздуха', 'Насадки\tконцентратор', 'Особенности\tпетля   для подвешивания', 'Длина   сетевого шнура\t1.8 м', 'Вес\t700  г'] Reference Микроволновая печь LG MS20R42D, белый (f1d7a6de205f4c9e):
#  ['Переключатели сенсорные, кнопочные', 'Доп. режимы звуковой сигнал отключения, автоматическая разморозка, автоматическое приготовление, ускоренная разморозка', 'Особенности дисплей, система равномерного распределения микроволн, подсветка камеры, блокировка от детей', 'Объем\t20   л', 'Мощность  микроволн\t700 Вт', 'Внутреннее  покрытие камеры\tэмаль', 'Диаметр  поддона\t245 мм', 'Режимы   работы\tразморозка', 'ШхВхГ\t45.50х25.20х32   см'] Reference Робот-пылесос Xiaomi Mijia Sweeping Vacuum Cleaner 1C (CN), белый (f1e45865f42886c4):
#  ['Тип контейнера\tдля пыли/воды', 'Объем контейнера для воды\t0.2 л', 'Работа от аккумулятора\tдо 90 мин', 'Тип   уборки\tсухая и влажная', 'Объем  контейнера для пыли\t0.6 л', 'Управление   со смартфона\tда', 'Тип   датчиков\tоптические', 'ШхГхВ\t35.30x35x8.10   см', 'Комплектация  турбощетка, боковая щетка', 'Доп.   функции таймер, сигнал при разрядке аккумулятора, программирование по дням недели, ограничение времени уборки, сигнал при застревании, построение карты помещения, расчет времени уборки', 'Режимы  работы местная уборка, движение вдоль стен, движение зигзагом', 'Особенности  конструкции мягкий бампер, гироскоп, встроенные часы'] Reference Процессор AMD Ryzen 9 5950X AM4, 16 x 3400 МГц, OEM (f1ef51ca6bab03d3):
#  ['Сокет AM4', 'Количество  ядер\t16 x 3400-4900 МГц', 'Объем  кэша L2/L3\t8 МБ/64 МБ', 'Оперативная  память\t2 x DDR4 3200 МГц', 'Тепловыделение   105 Вт', 'Техпроцесс\t7   нм', 'Количество  потоков\t32', 'Ядро   процессора Vermeer', 'Назначение настольный ПК, игровой', 'Дата  выхода\tQ4 2020'] Reference Процессор Intel Core i5-12400 LGA1700, 6 x 2500 МГц, OEM (f3218fffa4c09614):
#  ['Соке LGA1700', 'Тепловыделение 117 Вт', 'Дата выхода\tQ1 2022', 'Количество  ядер\t6 x 2500-4400 МГц', 'Объем  кэша L2/L3\t7.50 МБ/18 МБ', 'Интегрированная   графика\tUHD Graphics 730 1450 МГц', 'Техпроцесс\t10  нм', 'Количество  потоков\t12', 'Ядро  процессора Alder Lake-S', 'Назначение\tнастольный  ПК', 'Оперативная   память DDR5 3200/4800 МГц, 2 x DDR4'] Reference Встраиваемая посудомоечная машина Korting KDI 45570, серебристый (f325184a5c99c599):
#  ['Тип\tузкая', 'Ширина\t45 см', 'Таймер отсрочки запуска\tесть', 'Защита\tзащита от протечек', 'Число программ класс мойки: A, 8', 'Вместимость\t10   комплектов', 'Третий   уровень загрузки\tесть', '3-й  разбрызгиватель\tесть', 'Индикация   на полу\tлуч', 'Тип   защиты от протечек\tполная', 'Тип  сушки класс A, интенсивная'] Reference Сплит-система Hyundai HAC-09/T-PRO белый (f35afc760cecb50f):
#  ['Площадь помещения\t25 м²', 'Уровень шума внутреннего блока\t27 дБ - 38 дБ', 'Доп. режимы вентиляция, ночной, осушение', 'Цвет   товара\tбелый', 'Режим  работы\tохлаждение / обогрев', 'Класс  энергоэффективности\tA', 'Особенности   дисплей, индикация работы, регулировка направления воздушного потока, пульт ДУ, таймер включения/выключения'] Reference Накопительный электрический водонагреватель Ariston ABS ANDRIS LUX 6 OR (f3823ddbc3398737):
#  ['Максимальная температура воды\t75 °С', "Установка\tвертикальная на стену с нижней подводкой (½')", 'Управление\tмеханическое', 'Индикация\tвключения', 'Системы защиты предохранительный клапан, от перегрева', 'Объем   бака\t6 л', 'Потребляемая   мощность\t1500 Вт', 'Полезная   мощность\t1.5 кВт', 'Размеры   (ШxВxГ)\t315x315x250 мм', 'Покрытие  бака\tтитановая эмаль'] Reference 15.6" Ноутбук ASUS TUF Gaming F15 FX506HEB-HN169 1920x1080, Intel Core i5 11400H 2.7 ГГц, SSD 512 ГБ, NVIDIA GeForce RTX 3050 Ti, без ОС, 90NR0703-M04360, Eclipse Gray (f38501875b18a4a4):
#  ['Операционная система\tбез ОС', 'Экран\t15.6"   (1920x1080) IPS', 'Видеокарта\tNVIDIA   GeForce RTX 3050 Ti 4 ГБ', 'Время  работы от аккумулятора\t14.7 ч', 'Память  RAM 16 ГБ (3200 МГц), SSD 512 ГБ', 'Процессор\tIntel  Core i5 11400H (6x2.70 ГГц)'] Reference Сплит-система Electrolux EACS-09HAT/N3, белый (f3e10061c5a04f2c):
#  ['Площадь помещения\t25 м²', 'Фильтры\tдезодорирующий', 'Класс энергоэффективности\tA', 'Мощность  кондиционера\t9 BTU', 'Режим  работы\tохлаждение / обогрев', 'Мощность   охлаждения\t2640 Вт / обогрева: 2780 Вт', 'Уровень  шума внутреннего блока\t28 дБ', 'Доп.   режимы ночной, осушение, вентиляция', 'Особенности  индикация работы, таймер включения/выключения, регулировка направления воздушного потока, пульт ДУ, дисплей'] Reference Холодильник Whirlpool WTNF 902, бежевый (f440de22d764b2a3):
#  ['ШхВхГ 60х200х64 см', 'Особенности конструкции перевешиваемые двери, дисплей', 'Общий  объем 322 л', 'Размораживание  No Frost', 'Класс   энергопотребления A', 'Объем  холодильной камеры 247 л', 'Объем  морозильной камеры 75 л', 'Мощность  замораживания 9 кг/сутки', 'Режимы  суперзаморозка', 'Дополнительные   функции индикация температуры'] Reference 23.8" Монитор DELL S2422HZ, 1920x1080, 75 Гц, IPS, черный/серебристый (f4821600fc823f6d):
#  ['Экран\t1920x1080 (16:9)', 'Тип  матрицы\tIPS', 'Частота   обновления\t75 Гц; отклик: 4 мс', 'Яркость\t250  кд/м²;', 'Поддержка   FreeSync/G-Sync\tFreeSync', 'Покрытие  экрана\tантибликовое', 'Интерфейсы  вход DisplayPort, вход HDMI, USB Type-C', 'Особенности   поворот на 90 градусов, встроенный микрофон, встроенная веб-камера, регулировка по высоте, встроенные колонки'] Reference Сплит-система Royal Clima RC-PD28HN, белый (f497219eb0077f84):
#  ['Линейка\tPANDORA', 'Площадь помещения\t28 м²', 'Режим работы\tохлаждение / обогрев', 'Мощность   кондиционера\t9 BTU', 'Фильтр   тонкой очистки\tесть', 'Мощность   охлаждения\t2750 Вт / обогрева: 2950 Вт', 'Класс   энергоэффективности\tA', 'Уровень  шума внутреннего блока\t21.5 дБ - 38 дБ', 'Доп.  режимы экорежим, осушение, ночной, вентиляция, турбо', 'Фильтры   с ионами серебра, дезодорирующий', 'Особенности  дисплей, таймер включения/выключения, пульт ДУ, регулировка направления воздушного потока, индикация работы'] Reference Беспроводные наушники Xiaomi Buds 3 M2111E1 Черный (f4d135a1d7a3b3a0):
#  ['Тип устройства\tбеспроводные TWS-наушники', 'Конструкция\tвнутриканальные', 'Цвет   товара\tчерный', 'Тип   акустического оформления\tзакрытые', 'Конструктивные особенности\tмикрофон'] Reference Видеокарта MSI GeForce RTX 2060 VENTUS 12G OC, Retail (f50c3e7f0b02facb):
#  ['Комплектация\tRetail', 'Область применения\tигровая', 'TDP\t184 Вт', 'Разъем дополнительного питания\t8 pin', 'Максимальное разрешение\t7680x4320', 'Разъемы и интерфейсы выход DisplayPort x 3, выход HDMI', 'Объем   видеопамяти\t12288 МБ', 'Тип  памяти\tGDDR6', 'Частота   памяти\t14000 МГц', 'Шина  обмена с памятью\t192 бит', 'Частота   видеопроцессора\t1680 МГц', 'Техпроцесс\t12  нм', 'Тип   подключения\tPCI Express 3.0', 'Количество   поддерживаемых мониторов\t4', 'Поддержка   технологий поддержка HDCP, поддержка CUDA, поддержка трассировки лучей, поддержка Vulkan'] Reference Накопительный электрический водонагреватель Edisson ES 30 V, белый (f530b2c4727ad971):
#  ['Объем бака\t30 л', 'Потребляемая мощность\t1500 Вт', 'Время нагрева\t65 мин', 'Управление\tмеханическое', 'Полезная  мощность\t1.5 кВт', 'Максимальная   температура воды\t70 °С', 'Размеры   (ШxВxГ)\t365x501x378 мм', 'Покрытие  бака\tстеклокерамика', "Установка\tвертикальная   на стену с нижней подводкой (½')", 'Системы  защиты от перегрева, предохранительный клапан, обратный клапан', 'Индикация   нагрева, включения'] Reference Накопительный электрический водонагреватель Haier ES10V-Q2(R), серый (f57dee0aaa1d6762):
#  ['Потребляемая мощность\t1500 Вт', 'Размеры (ШxВxГ)\t350x350x270 мм', 'Управление\tмеханическое', 'Объем   бака\t10 л', 'Полезная  мощность\t1.5 кВт', 'Максимальная  температура воды\t75 °С', 'Время  нагрева\t20 мин', 'Покрытие  бака\tэмаль', "Установка\tвертикальная  на стену с верхней подводкой (½')", 'Системы   защиты\tпредохранительный клапан', 'Функции\tускоренный   нагрев'] Reference 43" Телевизор LG 43UP75006LF 2021 LED, HDR, черный (f5949f3c3d4611af):
#  ['Год создания модели\t2021', 'Платформа Smart TV\twebOS', 'Диагональ\t43"', 'Частота обновления экрана\t60 Гц', 'Форматы HDR\tHDR 10 Pro', 'Разрешение   HD\t4K UHD', 'Технология   экрана HDR, LED', 'Разъемы   и интерфейсы слот CI/CI+, Ethernet - RJ-45, вход HDMI x 2, USB Type-A, выход аудио оптический', 'Беспроводная  связь Bluetooth, Miracast, Wi-Fi, Airplay', 'Разрешение\t3840x2160', 'Тип   матрицы экрана\tIPS', 'Тип  подсветки\tDirect LED', 'Мощность  звука\t20 Вт', 'Экосистема   умного дома LG Smart ThinQ, Умный дом Яндекса, Apple HomeKit'] Reference Умные часы HUAWEI Watch GT 3 Active 46 мм, черный (f5cbd4fcc8474730):
#  ['Материал браслета/ремешка\tкаучук', 'Защищенность\tвлагозащита', 'Материал корпуса нерж. сталь, пластик', 'Мониторинг постоянное измерение пульса, акселерометр, мониторинг физической активности, термометр, мониторинг сна, измерение уровня кислорода в крови', 'Экран\t1.43"   (466x466) AMOLED', 'Размер   ремешка\t140-210', 'Совместимость   iOS, Android', 'Беспроводная   связь GPS, ГЛОНАСC, Bluetooth'] Reference Кофемашина De'Longhi Magnifica ECAM 22.110 (f66acf4527f0c708):
#  ['Давление помпы\t15 бар', 'Количество степеней помола\t13', 'Тип напитка капучино, эспрессо', 'Особенности конструкции индикатор уровня воды, контейнер для отходов, съемный лоток для сбора капель, индикатор включения', 'Тип  используемого кофе\tмолотый / зерновой', 'Приготовление   капучино\tручное', 'Одновременная  раздача на 2 чашки\tда', 'Материал  корпуса\tпластик', 'Настройки  жесткость воды, крепость кофе, температура кофе, объем порции горячей воды', 'Доп.   функции автоматическая декальцинация, автоотключение при неиспользовании, быстрый пар, подача горячей воды, подогрев чашек'] Reference 16.2" Ноутбук Apple Macbook Pro Late 2021 3456×2234, Apple M1 Pro, SSD 512 ГБ, Apple graphics 16-core, macOS, MK183LL/A, серый космос (f6711591cd55c091):
#  ['Экран\t16.2"   (3456×2234)', 'Процессор\tApple  M1 Pro', 'Время  работы от аккумулятора\t21 ч', 'Операционная  система\tmacOS', 'Память  SSD 512 ГБ, RAM 16 ГБ', 'Видеокарта  Apple graphics 16-core, встроенная'] Reference Индукционная плита Hyundai HYC-0105, белый (f67deaee31597443):
#  ['Настольная\tда', 'Управление\tэлектронное', 'Макс. потребляемая мощность\t2000 Вт', 'Особенности конструкции\tдисплей', 'ШхВхГ\t32х6.30х28 см', 'Защитное отключение конфорок', 'Материал  рабочей поверхности\tстеклокерамика', 'Число   индукционных конфорок\t1', 'Доп.   функции таймер, термостат'] Reference Wi-Fi роутер TP-LINK Archer C80 (f6d45c3ab6c52946):
#  ['Подключение к интернету (WAN)\tEthernet RJ-45', 'Частотный диапазон устройств Wi-Fi\t2.4 / 5 ГГц (одновременная работа)', 'Скорость портов\t1 Гбит/с', 'Количество LAN-портов 4', 'Стандарт Wi-Fi 802.11 n (Wi-Fi 4), g (Wi-Fi 3), a (Wi-Fi 2), ac (Wi-Fi 5), b (Wi-Fi 1)', 'Функции и особенности поддержка Mesh Wi-Fi, поддержка IPv6', 'Макс.   скорость беспроводного соединения 1900 Мбит/с'] Reference Видеокарта ASUS ROG Strix GeForce RTX 3080 Ti OC 12GB(ROG-STRIX-RTX3080TI-O12G-GAMING), Retail (f7443cc12811da93):
#  ['Комплектация\tRetail', 'Область применения\tигровая', 'Объем видеопамяти\t12288 МБ', 'Тип памяти\tGDDR6X', 'Частота  памяти\t19000 МГц', 'Шина  обмена с памятью\t384 бит', 'Частота видеопроцессора\t1815 МГц', 'Разъем дополнительного питания\t8 pin+8 pin+8 pin', 'Количество поддерживаемых мониторов\t4', 'Техпроцесс\t8  нм', 'Тип   подключения\tPCI Express 4.0', 'TDP\t350   Вт', 'Максимальное  разрешение\t7680x4320', 'Разъемы и интерфейсы выход HDMI x 2, выход DisplayPort x 3'] Reference МФУ лазерное Pantum M6507W (f90d8061194fbf26):
#  ['Назначение\tдля небольшого офиса', 'ЖК-панель\tда', 'Печать\tчерно-белая   лазерная', 'Макс.  формат печати\tA4 (210 × 297 мм)', 'Интерфейсы   Wi-Fi, AirPrint, USB', 'Функции отправка изображения по e-mail, сканирование, копирование'] Reference Компьютерная акустика Logitech Z407 (f9fc2a8afa5b2ff5):
#  ['пластик', 'Материал корпуса сабвуфера', 'MDF', 'Компьютерная акустика 2.1', 'Суммарная мощность 40 Вт', 'Подключение по USB', 'Диапазон частот 40 - 20000 Гц', 'Bluetooth', 'Материал  корпуса колонок', 'Пульт   ДУ'] Reference Стиральная машина Candy CBWM 914DW-07, белый (fb2f4122fc21be6f):
#  ['Установка\tвстраиваемая', 'ШхГхВ\t60х54х82 см', 'Защита от детей, от скачков питания', 'Загрузка\t9   кг', 'Скорость  отжима\t1400 об/мин', 'Класс  энергопотребления\tA+++', 'Доп.функции   контроль баланса, интеллектуальное управление стиркой, сигнал окончания стирки, выбор скорости отжима, контроль за уровнем пены, отложенный старт, выбор температуры стирки, прямой впрыск'] Reference Умные часы Xiaomi Mi Watch, темно-синий (fb35f7fa64691535):
#  ['Экран\t1.39" (454x454) AMOLED', 'Размер ремешка\t130-220', 'Защищенность\tвлагозащита', 'Беспроводная связь Galileo, Bluetooth, ГЛОНАСC, Beidou, GPS', 'Материал   корпуса\tполиамид', 'Материал  браслета/ремешка\tтермополиуретан', 'Емкость  аккумулятора\t420 мА·ч', 'Совместимость   Android, iOS', 'Мониторинг  постоянное измерение пульса, мониторинг сна, мониторинг физической активности, акселерометр, измерение уровня кислорода в крови, мониторинг калорий'] Reference Процессор Intel Core i5-12600KF LGA1700, 10 x 3700 МГц, OEM (fc0a307822fa30f3):
#  ['Объем кэша L2/L3\t9.50 МБ/20 МБ', 'Количество потоков\t16', 'Сокет  LGA1700', 'Количество   ядер\t10 x 3700-4900 МГц', 'Тепловыделение   150 Вт', 'Техпроцесс\t10   нм', 'Ядро   процессора Alder Lake-S', 'Дата   выхода\tQ4 2021', 'Оперативная   память 2 x DDR4, DDR5 3200/4800 МГц', 'Назначение   настольный ПК, игровой'] Reference Процессор AMD Athlon X4 950 AM4, 4 x 3500 МГц, OEM (fccdc0fdbefeeaa3):
#  ['Количество ядер\t4 x 3500-3800 МГц', 'Сокет  AM4', 'Объем   кэша L2\t2 МБ', 'Тепловыделение  65 Вт', 'Техпроцесс\t28  нм', 'Количество  потоков\t4', 'Ядро   процессора Bristol Ridge', 'Назначение\tнастольный  ПК', 'Дата  выхода\tQ3 2016', 'Оперативная  память\t2 x DDR4 2400 МГц'] Reference 23.8" Монитор Lenovo Tiny-In-One 24 Gen4, 1920x1080, 60 Гц, IPS, черный (fdff5884f8e0cdaf):
#  ['Частота обновления\t60 Гц; отклик: 4 мс', 'Интерфейсы\tвход DisplayPort', 'Яркость\t250 кд/м²; контрастность: 1000:1', 'Экран\t1920x1080  (16:9)', 'Тип  матрицы\tIPS', 'Покрытие   экрана антибликовое, матовое', 'Особенности  встроенные колонки, регулировка по высоте, встроенный микрофон, встроенная веб-камера, поворот на 90 градусов'] Reference Накопительный электрический водонагреватель Thermex Ultra Slim IU 30, белый (fee1d1dc53f135d1):
#  ['Время нагрева\t50 мин', "Установка\tвертикальная на стену с нижней подводкой (½')", 'Управление\tмеханическое', 'Системы защиты обратный клапан, предохранительный клапан', 'Объем   бака\t30 л', 'Потребляемая  мощность\t2000 Вт', 'Полезная  мощность\t2 кВт', 'Максимальная   температура воды\t75 °С', 'Размеры   (ШxВxГ)\t270x800x285 мм', 'Покрытие   бака\tнерж.сталь', 'Функции\tускоренный   нагрев', 'Индикация   включения, нагрева'] Reference 15.6" Ноутбук Lenovo IdeaPad Gaming 315IHU6 1920x1080, Intel Core i5 11300H 3.1 ГГц, SSD 512 ГБ, NVIDIA GeForce RTX 3050, без ОС, 82K10011RK, shadow black (ff5da4be6fa60c4b):
#  ['Видеокарта\tNVIDIA GeForce RTX 3050 4 ГБ', 'Время  работы от аккумулятора\t8 ч', 'Память RAM 8 ГБ (3200 МГц), SSD 512 ГБ', 'Экран\t15.6"   (1920x1080) IPS', 'Процессор\tIntel  Core i5 11300H (4x3.10 ГГц)', 'Операционная  система\tбез ОС']

# %%
def get_referrers(ref: Product):
    assert ref.is_reference
    return [p for p in products if p.reference_id == ref.product_id] # TODO: use filter


def describe_reference(ref: Product):
    print(ref)
    print()
    print(*get_referrers(ref), sep='\n')

# %%
describe_reference(references[11])
# Out:
# Reference Микроволновая печь LG MS2535GIS, черный (070dd48327cad4d5):
#  ['Объем\t25 л', 'Инверторное управление мощностью\tда', 'Внутреннее покрытие камеры\tэмаль', 'Переключатели\tсенсорные', 'Мощность  микроволн\t1000 Вт', 'Диаметр  поддона\t292 мм', 'Режимы   работы\tразморозка', 'ШхВхГ\t47.60х27.20х36.80   см', 'Особенности   подсветка камеры, дисплей, блокировка от детей', 'Доп.  режимы автоматический разогрев, программирование процесса приготовления, звуковой сигнал отключения, автоматическое поддержание температуры, автоматическое приготовление, автоматическая разморозка']
#
# Referrer of 070dd48327cad4d5 Микроволновая печь LG MS2535GIS черный (инвертор) (41b312152ddb3af7):
#  ['Переключатели\tсенсорные', 'Внутреннее   покрытие камеры\tэмаль', 'Диаметр  поддона\t292 мм', 'Режимы  работы\tразморозка', 'ШхВхГ\t47.60х27.20х36.80  см', 'Особенности  подсветка камеры, дисплей, блокировка от детей', 'Доп.  режимы звуковой сигнал отключения, автоматическая разморозка, автоматическое поддержание температуры, программирование процесса приготовления, автоматическое приготовление, автоматический разогрев']
# Referrer of 070dd48327cad4d5 Микроволновая печь соло LG MS2535GIS (71627867aa1423f7):
#  ['Переключатели\tсенсорные', 'Режимы  работы\tразморозка', 'Особенности   блокировка от детей, дисплей, подсветка камеры', 'Инверторное   управление мощностью\tда', 'ШхВхГ\t47.60х27.20х36.80   см', 'Объем\t25   л']
# Referrer of 070dd48327cad4d5 Микроволновая печь LG MS2535GIS черный (922e8f6d086faeab):
#  ['Доп.  режимы автоматическое приготовление, автоматический разогрев, звуковой сигнал отключения, автоматическая разморозка, автоматическое поддержание температуры, программирование процесса приготовления', 'Переключатели\tсенсорные', 'Объем\t25 л', 'Режимы  работы\tразморозка', 'Инверторное   управление мощностью\tда', 'ШхВхГ\t47.60х27.20х36.80  см', 'Диаметр  поддона\t292 мм', 'Особенности  подсветка камеры, блокировка от детей, дисплей']
# Referrer of 070dd48327cad4d5 Микроволновая печь соло LG MS2535GIS (a660f2c7ebc642d1):
#  ['Переключатели\tсенсорные', 'Диаметр поддона\t292 мм', 'Внутреннее  покрытие камеры\tэмаль', 'Режимы   работы\tразморозка', 'Инверторное  управление мощностью\tда', 'Мощность   микроволн\t1000 Вт']
# Referrer of 070dd48327cad4d5 Микроволновая печь LG MS 2535 GIS (f0222dceeb2d1d03):
#  ['Объем\t25 л', 'Инверторное  управление мощностью\tда', 'Режимы  работы\tразморозка', 'Особенности блокировка от детей, подсветка камеры, дисплей']

# %%
from sklearn.model_selection import train_test_split


products_train, products_test = train_test_split(
    products, test_size=0.4, random_state=42
)
all_products = products_train + references

# %%
'''
chars = {}


def calc_chars(s):
    for c in s:
        if c in chars:
            chars[c] += 1
        else:
            chars[c] = 1


for product in all_products:
    calc_chars(product.name)
    for prop in product.props:
        calc_chars(prop)

import numpy as np

if ' ' in chars:
    chars.pop(' ')
if '\t' in chars:
    chars.pop('\t')

char_keys = sorted(list(chars.keys()))
char2ind = {c : i for i, c in enumerate(char_keys)}


def build_vector(s):
    v = np.zeros((len(char_keys)), dtype=int)
    for c in s:
        if c in char2ind:
            v[char2ind[c]] += 1
    return v.astype(float)
'''
# Out:
# "\nchars = {}\n\n\ndef calc_chars(s):\n    for c in s:\n        if c in chars:\n            chars[c] += 1\n        else:\n            chars[c] = 1\n\n\nfor product in all_products:\n    calc_chars(product.name)\n    for prop in product.props:\n        calc_chars(prop)\n\nimport numpy as np\n\nif ' ' in chars:\n    chars.pop(' ')\nif '\t' in chars:\n    chars.pop('\t')\n\nchar_keys = sorted(list(chars.keys()))\nchar2ind = {c : i for i, c in enumerate(char_keys)}\n\n\ndef build_vector(s):\n    v = np.zeros((len(char_keys)), dtype=int)\n    for c in s:\n        if c in char2ind:\n            v[char2ind[c]] += 1\n    return v.astype(float)\n"

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

def get_product_payload(product: Product) -> str:
    return product.name + ' ' + ' '.join(product.props)

def tokenize(payload: str, language='russian') -> [str]:
    words = word_tokenize(payload, language=language)
    words = list(map(lambda w: w.lower(), words))
    words = list(filter(lambda w: w not in stopwords.words(language), words))

    return words

# %%
#nltk.download('punkt')
#nltk.download('stopwords')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from spacy.lang.ru import STOP_WORDS as RU_STOP_WORDS
from spacy.lang.en import STOP_WORDS as EN_STOP_WORDS
from spacy.lang.ru import Russian

def products2corpus(prods):
    return [p.name + ' ' + ' '.join(p.props) for p in prods]

train_corpus = products2corpus(all_products)
test_corpus = products2corpus(products_test)

tfidf = TfidfVectorizer(  #TfidfVectorizer(sublinear_tf=True, norm='l2', ngram_range=(1, 2),
    stop_words=RU_STOP_WORDS or EN_STOP_WORDS)#,  tokenizer=tokenize)
X_train = tfidf.fit_transform(train_corpus).toarray()

X_test = tfidf.transform(test_corpus).toarray()

# %%
tfidf.build_tokenizer()("Переключатели\tсенсорные', 'Внутреннее   покрытие камеры\tэмаль', 'Диаметр  поддона\t292 мм', 'Режимы  работы\tразморозка', 'ШхВхГ\t47.60х27.20х36.80  см', 'Особенности  подсветка камеры, дисплей, блокировка от дете")
# Out:
# ['Переключатели',
#  'сенсорные',
#  'Внутреннее',
#  'покрытие',
#  'камеры',
#  'эмаль',
#  'Диаметр',
#  'поддона',
#  '292',
#  'мм',
#  'Режимы',
#  'работы',
#  'разморозка',
#  'ШхВхГ',
#  '47',
#  '60х27',
#  '20х36',
#  '80',
#  'см',
#  'Особенности',
#  'подсветка',
#  'камеры',
#  'дисплей',
#  'блокировка',
#  'от',
#  'дете']

# %%
ref_id2ind = {
    ref.product_id : i for i, ref in enumerate(references)
}

def build_target(prods):
    return np.array([
        ref_id2ind[p.product_id if p.is_reference else p.reference_id] for p in prods
    ])

y_train = build_target(all_products)

y_test = build_target(products_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import RidgeClassifier, SGDClassifier
from sklearn.base import ClassifierMixin

models = [
    RandomForestClassifier(random_state=0),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=0),
    RidgeClassifier(),
    SGDClassifier()
]


def test_model(model: ClassifierMixin):
    model_name = model.__class__.__name__
    model.fit(X_train, y_train)

    train_acc = model.score(X_train, y_train)
    test_acc = model.score(X_test, y_test)

    print(model_name, f"train: {train_acc}, test: {test_acc}")


for model in models:
    test_model(model)
# Out:
# RandomForestClassifier train: 0.9985974754558204, test: 0.8453237410071942
# LinearSVC train: 0.9981299672744273, test: 0.9442446043165468
# MultinomialNB train: 0.5568022440392707, test: 0.2670863309352518
# LogisticRegression train: 0.7554932211313699, test: 0.4721223021582734
# RidgeClassifier train: 0.9934548854604955, test: 0.9217625899280576
# SGDClassifier train: 0.9939223936418887, test: 0.8803956834532374

# %%
from sklearn.svm import LinearSVC, SVC
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import SGDClassifier

'''
grid = GridSearchCV(
    SGDClassifier(verbose=1), {
    'loss' : ['hinge', 'log_loss', 'log', 'modified_huber', 'squared_hinge',
     'perceptron', 'squared_error', 'huber', 'epsilon_insensitive',
     'squared_epsilon_insensitive'],
    'penalty' : ['l2', 'l1', 'elasticnet'],
    'alpha' : [1e-3, 1e-4]
}, scoring=lambda model, x, y: model.score(x, y), n_jobs=10, verbose=10, cv=3)
'''

grid = GridSearchCV(LinearSVC(), {
    'penalty' : ['l1', 'l2'],
    'loss' : ['hinge', 'squared_hinge'],
    'C' : np.arange(0, 1, 0.1),

}, scoring=lambda model, x, y: model.score(x, y), n_jobs=10, verbose=1)


grid.fit(
    np.concatenate([X_train, X_test]),
    np.concatenate([y_train, y_test])
)

'''
'penalty' : ['l1', 'l2'],
'loss' : ['hinge', 'squared_hinge'],
'C' : np.arange(0, 1, 0.1),
'''
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# C:\Users\densh\.conda\envs\clip\lib\site-packages\sklearn\model_selection\_split.py:680: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\densh\.conda\envs\clip\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 110 fits failed out of a total of 200.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\densh\.conda\envs\clip\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\densh\.conda\envs\clip\lib\site-packages\sklearn\svm\_classes.py", line 257, in fit
#     self.coef_, self.intercept_, n_iter_ = _fit_liblinear(
#   File "C:\Users\densh\.conda\envs\clip\lib\site-packages\sklearn\svm\_base.py", line 1204, in _fit_liblinear
#     solver_type = _get_liblinear_solver_type(multi_class, penalty, loss, dual)
#   File "C:\Users\densh\.conda\envs\clip\lib\site-packages\sklearn\svm\_base.py", line 1043, in _get_liblinear_solver_type
#     raise ValueError(
# ValueError: Unsupported set of arguments: The combination of penalty='l1' and loss='hinge' is not supported, Parameters: penalty='l1', loss='hinge', dual=True
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\densh\.conda\envs\clip\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\densh\.conda\envs\clip\lib\site-packages\sklearn\svm\_classes.py", line 257, in fit
#     self.coef_, self.intercept_, n_iter_ = _fit_liblinear(
#   File "C:\Users\densh\.conda\envs\clip\lib\site-packages\sklearn\svm\_base.py", line 1205, in _fit_liblinear
#     raw_coef_, n_iter_ = liblinear.train_wrap(
#   File "sklearn\svm\_liblinear.pyx", line 52, in sklearn.svm._liblinear.train_wrap
# ValueError: b'C <= 0'
#
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\densh\.conda\envs\clip\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\densh\.conda\envs\clip\lib\site-packages\sklearn\svm\_classes.py", line 257, in fit
#     self.coef_, self.intercept_, n_iter_ = _fit_liblinear(
#   File "C:\Users\densh\.conda\envs\clip\lib\site-packages\sklearn\svm\_base.py", line 1204, in _fit_liblinear
#     solver_type = _get_liblinear_solver_type(multi_class, penalty, loss, dual)
#   File "C:\Users\densh\.conda\envs\clip\lib\site-packages\sklearn\svm\_base.py", line 1043, in _get_liblinear_solver_type
#     raise ValueError(
# ValueError: Unsupported set of arguments: The combination of penalty='l1' and loss='squared_hinge' are not supported when dual=True, Parameters: penalty='l1', loss='squared_hinge', dual=True
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\densh\.conda\envs\clip\lib\site-packages\sklearn\model_selection\_search.py:953: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan 0.95016944
#         nan 0.92402316        nan 0.95109158        nan 0.9437079
#         nan 0.95139927        nan 0.95170412        nan 0.95139832
#         nan 0.95601134        nan 0.95170507        nan 0.95847241
#         nan 0.95385892        nan 0.95970223        nan 0.9544743
#         nan 0.96124069        nan 0.95478199        nan 0.96216283
#         nan 0.95508968        nan 0.9630859 ]
#   warnings.warn(
# "\n'penalty' : ['l1', 'l2'],\n'loss' : ['hinge', 'squared_hinge'],\n'C' : np.arange(0, 1, 0.1),\n"

# %%
grid.best_params_
# Out:
# {'C': 0.9, 'loss': 'squared_hinge', 'penalty': 'l2'}

# %%
grid.best_score_
# Out:
# 0.9630859033439678

# %%
0/0

# %% [markdown]
# ## Best models so far

# %%
LinearSVC(C=0.9)

# %%
ref_id2ind = {
    ref.product_id : i for i, ref in enumerate(references)
}


def build_dataset(prods):
    x = np.array([
        sum(map(build_vector, [p.name] + p.props)) for p in prods
    ])
    x = x / np.linalg.norm(x, axis=1, keepdims=True)

    y = np.array([
         ref_id2ind[p.product_id if p.is_reference else p.reference_id] for p in prods
    ])

    return x, y

# %%
x_train, y_train = build_dataset(references + products_train)
x_test, y_test = build_dataset(products_test)

# %%
x_train.shape

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier()

# %%
from sklearn.model_selection import GridSearchCV

grid = {'n_neighbors' : [1,4], 'algorithm' : ['auto', 'ball_tree', 'kd_tree', 'brute']}
grid_search = GridSearchCV(estimator=knn_model, param_grid=grid)
grid_search.fit(x_train, y_train)

# %%
print(grid_search.best_params_)

# %%
grid_search.score(x_test, y_test)

# %%
# !python -m spacy download ru_core_news_sm

# %%
import spacy

nlp = spacy.load("ru_core_news_sm")
doc = nlp(products[0].name)
print(doc.text)
for token in doc:
    print(token.text, token.pos_, token.dep_)
